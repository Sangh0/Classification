# %% [markdown]
# <a href="https://colab.research.google.com/github/Sangh0/Classification/blob/main/alexnet_practice2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AlexNet Practice
#
# ## Step 1. Import packages and modules

# %%
import os
import random
import time
import numpy as np
import matplotlib.pyplot as plt
from tqdm.auto import tqdm
from sklearn.model_selection import train_test_split
from multiprocessing import cpu_count

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.datasets as dset
import torchvision.models as models
from torch.utils.data import DataLoader, SubsetRandomSampler
from torchsummary import summary

# %%
SEED = 42

def RANDOM_SEED(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    os.environ["PYTHONHASHSEED"] = str(seed)

RANDOM_SEED(SEED)

# %% [markdown]
# ## Step 2. Set hyperparameters

# %%
Config = {
    'batch_size': 128,
    'lr': 0.01,
    'epochs': 90,
    'weight_decay': 5e-4,
    'momentum': 0.9,
}

# %% [markdown]
# ## Step 3. Load Dataset

# %%
# augmentation
train_transforms_ = transforms.Compose([
    transforms.Resize((256,256)),
    transforms.RandomCrop((224,224)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
])

valid_transforms_ = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
])

# Load CIFAR-10 
# train: 50000 (5000 per class), test: 10000 (1000 per class)
train_data = dset.CIFAR10(
    root='./cifar10', 
    train=True, 
    download=True, 
    transform=train_transforms_,
)

test_data = dset.CIFAR10(
    root='./cifar10',
    train=False,
    download=True,
    transform=valid_transforms_,
)

# stratify split (train: 80%, valid: 20%)
train_index, valid_index = train_test_split(
    np.arange(len(train_data)),
    test_size=0.2,
    random_state=SEED,
    shuffle=True,
    stratify=train_data.targets,
)

# define data loaders for batch learning
train_loader = DataLoader(
    train_data,
    batch_size=Config['batch_size'],
    sampler=SubsetRandomSampler(train_index),
    drop_last=True,
    num_workers=int(cpu_count()/2),
)

valid_loader = DataLoader(
    train_data,
    batch_size=Config['batch_size'],
    sampler=SubsetRandomSampler(valid_index),
    drop_last=True,
    num_workers=int(cpu_count()/2),
)

test_loader = DataLoader(
    test_data,
    batch_size=Config['batch_size'],
    shuffle=False,
    drop_last=False,
    num_workers=int(cpu_count()/2),
)

classes = ('Airplane', 'Car', 'Bird', 'Cat', 'Deer', 'Dog', 'Frog', 'Horse', 'Ship', 'Truck')
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./cifar10/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./cifar10/cifar-10-python.tar.gz to ./cifar10
# Files already downloaded and verified

# %% [markdown]
# ## Step 4-1. Build Model (Random Weights)

# %%
class AlexNet(nn.Module):
    
    def __init__(
        self,
        in_dim=3,
        filters=[96, 256, 384, 384, 256],
        dropout=0.5,
        num_classes=1000,
    ):
        super(AlexNet, self).__init__()
        
        self.features = nn.Sequential(
            nn.Conv2d(in_dim, filters[0], kernel_size=11, stride=4, padding=2),
            nn.ReLU(inplace=True),
            nn.LocalResponseNorm(size=5, alpha=0.0001, beta=0.75, k=2),
            nn.MaxPool2d(kernel_size=3, stride=2),
            
            nn.Conv2d(filters[0], filters[1], kernel_size=5, stride=1, padding=2),
            nn.ReLU(inplace=True),
            nn.LocalResponseNorm(size=5, alpha=0.0001, beta=0.75, k=2),
            nn.MaxPool2d(kernel_size=3, stride=2), 
            
            nn.Conv2d(filters[1], filters[2], kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(filters[2], filters[3], kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(filters[3], filters[4], kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
        )
        
        self.classifier = nn.Sequential(
            nn.Dropout(dropout),
            nn.Linear(filters[4]*6*6, 4096),
            nn.ReLU(inplace=True),

            nn.Dropout(dropout),
            nn.Linear(4096, 4096),
            nn.ReLU(inplace=True),
      
            nn.Linear(4096, num_classes),
        )

        self._init_weights_()
        
    def forward(self, x):
        B = x.size(0)
        x = self.features(x)
        x = x.view(B, -1)
        x = self.classifier(x)
        return x

    def _init_weights_(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.normal_(m.weight, mean=0, std=0.01)
                nn.init.constant_(m.bias, 1)
            elif isinstance(m, nn.Linear):
                nn.init.constant_(m.bias, 1)
        
        nn.init.constant_(self.features[0].bias, 0)
        nn.init.constant_(self.features[8].bias, 0)

# %% [markdown]
# ## Step 4-2. Build Model (pre-trained weights)

# %%
class AlexNet(nn.Module):

    def __init__(
        self,
        dropout=None,
        num_classes=1000,
        del_conv=False,
        init_weights=False,
    ):
        super().__init__()

        self.model = models.alexnet(pretrained=True)

        if del_conv:
            del self.model.features[8]
            del self.model.features[9]
            self.model.features[10] = nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1)

        if dropout is not None:
            self.model.classifier[0] = nn.Dropout(p=dropout, inplace=False)
            self.model.classifier[3] = nn.Dropout(p=dropout, inplace=False)
            
        self.model.classifier[-1] = nn.Linear(4096, num_classes)

        if init_weights:
            self._init_weights_()

    def forward(self, x):
        return self.model(x)

    def _init_weights_(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.normal_(m.weight, mean=0, std=0.01)
                nn.init.constant_(m.bias, 1)
            elif isinstance(m, nn.Linear):
                nn.init.constant_(m.bias, 1)
        
        nn.init.constant_(self.features[0].bias, 0)
        nn.init.constant_(self.features[8].bias, 0)

# %% [markdown]
# # Step 5. Set Callbacks

# %%
class EarlyStopping(object):
    
    def __init__(
        self, 
        patience=7, 
        verbose=False, 
        delta=0, 
        path='es_checkpoint.pt', 
        trace_func=print,
    ):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path
        self.trace_func = trace_func
        
    def __call__(self, val_loss, model):
        score = -val_loss
        if self.best_score is None:
            self.best_score = score
            self.save_model(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            self.trace_func(f'\nEarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_model(val_loss, model)
            self.counter = 0
            
    def save_model(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            self.trace_func(f'\nValidation loss decreased ({self.val_loss_min:.3f} --> {val_loss:.3f}).  Saving model ...')
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss

# %% [markdown]
# ## Step 6. Train Model

# %%
class TrainModel(object):
    
    def __init__(
        self,
        model,
        lr=Config['lr'],
        epochs=Config['epochs'],
        weight_decay=Config['weight_decay'],
        lr_scheduling=True,
        check_point=True,
        early_stop=False,
        es_path=None,
        train_log_step=10,
        valid_log_step=5,
    ):
        assert (early_stop==True and es_path is not None) or \
            (early_stop==False and es_path is None), \
            'If you set early stop, then es_path must be not None'

        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

        ######### Multi GPU training #########
        if torch.cuda.device_count() > 1:
            print("Let's use", torch.cuda.device_count(), "GPUs!")
            model = nn.DataParallel(model)
            self.model = model.to(self.device)
        ######################################

        ######### Single GPU training #########
        else:
            print('Single GPU training!')
            self.model = model.to(self.device)
        #######################################

        self.loss_func = nn.CrossEntropyLoss().to(self.device)
        
        self.epochs = epochs
        
        self.optimizer = optim.SGD(
            self.model.parameters(),
            momentum=Config['momentum'],
            lr=lr,
            weight_decay=weight_decay,
        )

        self.lr_scheduling = lr_scheduling
        self.lr_scheduler = optim.lr_scheduler.ReduceLROnPlateau(
            self.optimizer,
            mode='min',
            factor=0.1,
            patience=10,
            verbose=True,
            min_lr=lr*1e-2,
        )

        os.makedirs('./weights', exist_ok=True)
        es_path = './weights/'+es_path if es_path is not None else './weights/es_weight.pt'
        self.early_stop = early_stop
        self.es = EarlyStopping(patience=15, verbose=True, path=es_path)
        
        self.train_log_step = train_log_step
        self.valid_log_step = valid_log_step
        
    def fit(self, train_data, validation_data):
        print('Start Model Training...!')
        loss_list, acc_list = [], []
        val_loss_list, val_acc_list = [], []
        start_training = time.time()
        pbar = tqdm(range(self.epochs), total=int(self.epochs))
        for epoch in pbar:
            init_time = time.time()
            
            ######### Train Phase #########
            train_loss, train_acc = self.train_on_batch(
                train_data, self.train_log_step,
            )

            loss_list.append(train_loss)
            acc_list.append(train_acc)

            ######### Validate Phase #########
            valid_loss, valid_acc = self.validate_on_batch(
                validation_data, self.valid_log_step,
            )

            val_loss_list.append(valid_loss)
            val_acc_list.append(valid_acc)

            end_time = time.time()
            
            print(f'\n{"="*30} Epoch {epoch+1}/{self.epochs} {"="*30}'
                  f'\ntime: {end_time-init_time:.2f}s'
                  f'   lr = {self.optimizer.param_groups[0]["lr"]}')
            print(f'\ntrain average loss: {train_loss:.3f}'
                  f'  accuracy: {train_acc:.3f}')
            print(f'\nvalid average loss: {valid_loss:.3f}'
                  f'  accuracy: {valid_acc:.3f}')
            print(f'\n{"="*76}')
            
            if self.lr_scheduling:
                self.lr_scheduler.step(valid_loss)

            if self.early_stop:
                self.es(valid_loss, self.model)
                if self.es.early_stop:
                    print('\n##########################\n'
                          '##### Early Stopping #####\n'
                          '##########################')
                    break

        end_training = time.time()
        print(f'\nTotal time for training is {end_training-start_training:.2}s')
        
        return {
            'model': self.model,
            'loss': loss_list,
            'acc': acc_list,
            'val_loss': val_loss_list,
            'val_acc': val_acc_list,
        }
        
    @torch.no_grad()
    def validate_on_batch(self, validation_data, log_step):
        self.model.eval()
        batch_loss, batch_acc = 0, 0
        for batch, (images, labels) in enumerate(validation_data):
            images = images.to(self.device)
            labels = labels.to(self.device)
            
            outputs = self.model(images)
            loss = self.loss_func(outputs, labels)
            output_index = torch.argmax(outputs, dim=1)
            acc = (output_index==labels).sum()/len(outputs)
            
            if batch == 0:
                print(f'\n{" "*10} Validate Step {" "*10}')
                
            if (batch+1) % log_step == 0:
                print(f'\n[Batch {batch+1}/{len(validation_data)}]'
                      f'  valid loss: {loss:.3f}  accuracy: {acc:.3f}')
                
            batch_loss += loss.item()
            batch_acc += acc.item()
            
            del images; del labels; del outputs
            torch.cuda.empty_cache()
            
        return batch_loss/(batch+1), batch_acc/(batch+1)
        
    def train_on_batch(self, train_data, log_step):
        self.model.train()
        batch_loss, batch_acc = 0, 0
        for batch, (images, labels) in enumerate(train_data):
            images = images.to(self.device)
            labels = labels.to(self.device)

            self.optimizer.zero_grad()

            outputs = self.model(images)
            loss = self.loss_func(outputs, labels)
            output_index = torch.argmax(outputs, dim=1)
            acc = (output_index==labels).sum()/len(outputs)
            
            loss.backward()
            self.optimizer.step()
            
            
            if batch == 0:
                print(f'\n{" "*10} Train Step {" "*10}')
                
            if (batch+1) % log_step == 0:
                print(f'\n[Batch {batch+1}/{len(train_data)}]'
                      f'  train loss: {loss:.3f}  accuracy: {acc:.3f}')
                
            batch_loss += loss.item()
            batch_acc += acc.item()
            
            del images; del labels; del outputs
            torch.cuda.empty_cache()
        
        return batch_loss/(batch+1), batch_acc/(batch+1)

# %%
# case 4: epoch 150 with learning rate 1e-4
epoch150_lower_lr_alexnet = AlexNet(num_classes=10)
summary(epoch150_lower_lr_alexnet, (3, 224, 224), device='cpu')

case4_model = TrainModel(
    model=epoch150_lower_lr_alexnet,
    lr=1e-4,
    epochs=150,
    train_log_step=1000,
    valid_log_step=300,
    early_stop=True,
    es_path='epoch150_lr1e-4.pt',
)

history4 = case4_model.fit(train_loader, valid_loader)
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
#   0%|          | 0.00/233M [00:00<?, ?B/s]
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 55, 55]          23,296
#               ReLU-2           [-1, 64, 55, 55]               0
#          MaxPool2d-3           [-1, 64, 27, 27]               0
#             Conv2d-4          [-1, 192, 27, 27]         307,392
#               ReLU-5          [-1, 192, 27, 27]               0
#          MaxPool2d-6          [-1, 192, 13, 13]               0
#             Conv2d-7          [-1, 384, 13, 13]         663,936
#               ReLU-8          [-1, 384, 13, 13]               0
#             Conv2d-9          [-1, 256, 13, 13]         884,992
#              ReLU-10          [-1, 256, 13, 13]               0
#            Conv2d-11          [-1, 256, 13, 13]         590,080
#              ReLU-12          [-1, 256, 13, 13]               0
#         MaxPool2d-13            [-1, 256, 6, 6]               0
# AdaptiveAvgPool2d-14            [-1, 256, 6, 6]               0
#           Dropout-15                 [-1, 9216]               0
#            Linear-16                 [-1, 4096]      37,752,832
#              ReLU-17                 [-1, 4096]               0
#           Dropout-18                 [-1, 4096]               0
#            Linear-19                 [-1, 4096]      16,781,312
#              ReLU-20                 [-1, 4096]               0
#            Linear-21                   [-1, 10]          40,970
#           AlexNet-22                   [-1, 10]               0
# ================================================================
# Total params: 57,044,810
# Trainable params: 57,044,810
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 8.37
# Params size (MB): 217.61
# Estimated Total Size (MB): 226.55
# ----------------------------------------------------------------
# Single GPU training!
# Start Model Training...!
#   0%|          | 0/150 [00:00<?, ?it/s]
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 1/150 ==============================
# time: 79.05s   lr = 0.0001
#
# train average loss: 1.220  accuracy: 0.582
#
# valid average loss: 0.750  accuracy: 0.743
#
# ============================================================================
#
# Validation loss decreased (inf --> 0.750).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 2/150 ==============================
# time: 96.56s   lr = 0.0001
#
# train average loss: 0.742  accuracy: 0.741
#
# valid average loss: 0.627  accuracy: 0.781
#
# ============================================================================
#
# Validation loss decreased (0.750 --> 0.627).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 3/150 ==============================
# time: 103.09s   lr = 0.0001
#
# train average loss: 0.652  accuracy: 0.772
#
# valid average loss: 0.558  accuracy: 0.810
#
# ============================================================================
#
# Validation loss decreased (0.627 --> 0.558).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 4/150 ==============================
# time: 103.65s   lr = 0.0001
#
# train average loss: 0.601  accuracy: 0.790
#
# valid average loss: 0.524  accuracy: 0.820
#
# ============================================================================
#
# Validation loss decreased (0.558 --> 0.524).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 5/150 ==============================
# time: 96.12s   lr = 0.0001
#
# train average loss: 0.566  accuracy: 0.802
#
# valid average loss: 0.501  accuracy: 0.825
#
# ============================================================================
#
# Validation loss decreased (0.524 --> 0.501).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 6/150 ==============================
# time: 92.09s   lr = 0.0001
#
# train average loss: 0.542  accuracy: 0.811
#
# valid average loss: 0.479  accuracy: 0.830
#
# ============================================================================
#
# Validation loss decreased (0.501 --> 0.479).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 7/150 ==============================
# time: 90.47s   lr = 0.0001
#
# train average loss: 0.518  accuracy: 0.820
#
# valid average loss: 0.460  accuracy: 0.839
#
# ============================================================================
#
# Validation loss decreased (0.479 --> 0.460).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 8/150 ==============================
# time: 91.10s   lr = 0.0001
#
# train average loss: 0.499  accuracy: 0.826
#
# valid average loss: 0.446  accuracy: 0.844
#
# ============================================================================
#
# Validation loss decreased (0.460 --> 0.446).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 9/150 ==============================
# time: 90.94s   lr = 0.0001
#
# train average loss: 0.488  accuracy: 0.831
#
# valid average loss: 0.441  accuracy: 0.844
#
# ============================================================================
#
# Validation loss decreased (0.446 --> 0.441).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 10/150 ==============================
# time: 90.99s   lr = 0.0001
#
# train average loss: 0.468  accuracy: 0.837
#
# valid average loss: 0.429  accuracy: 0.850
#
# ============================================================================
#
# Validation loss decreased (0.441 --> 0.429).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 11/150 ==============================
# time: 91.12s   lr = 0.0001
#
# train average loss: 0.461  accuracy: 0.838
#
# valid average loss: 0.428  accuracy: 0.849
#
# ============================================================================
#
# Validation loss decreased (0.429 --> 0.428).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 12/150 ==============================
# time: 92.52s   lr = 0.0001
#
# train average loss: 0.450  accuracy: 0.844
#
# valid average loss: 0.416  accuracy: 0.855
#
# ============================================================================
#
# Validation loss decreased (0.428 --> 0.416).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 13/150 ==============================
# time: 92.47s   lr = 0.0001
#
# train average loss: 0.436  accuracy: 0.848
#
# valid average loss: 0.407  accuracy: 0.859
#
# ============================================================================
#
# Validation loss decreased (0.416 --> 0.407).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 14/150 ==============================
# time: 93.29s   lr = 0.0001
#
# train average loss: 0.429  accuracy: 0.849
#
# valid average loss: 0.400  accuracy: 0.860
#
# ============================================================================
#
# Validation loss decreased (0.407 --> 0.400).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 15/150 ==============================
# time: 93.27s   lr = 0.0001
#
# train average loss: 0.420  accuracy: 0.850
#
# valid average loss: 0.392  accuracy: 0.865
#
# ============================================================================
#
# Validation loss decreased (0.400 --> 0.392).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 16/150 ==============================
# time: 93.01s   lr = 0.0001
#
# train average loss: 0.418  accuracy: 0.853
#
# valid average loss: 0.392  accuracy: 0.864
#
# ============================================================================
#
# Validation loss decreased (0.392 --> 0.392).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 17/150 ==============================
# time: 92.88s   lr = 0.0001
#
# train average loss: 0.406  accuracy: 0.857
#
# valid average loss: 0.379  accuracy: 0.870
#
# ============================================================================
#
# Validation loss decreased (0.392 --> 0.379).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 18/150 ==============================
# time: 92.63s   lr = 0.0001
#
# train average loss: 0.397  accuracy: 0.862
#
# valid average loss: 0.377  accuracy: 0.868
#
# ============================================================================
#
# Validation loss decreased (0.379 --> 0.377).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 19/150 ==============================
# time: 93.08s   lr = 0.0001
#
# train average loss: 0.394  accuracy: 0.860
#
# valid average loss: 0.374  accuracy: 0.869
#
# ============================================================================
#
# Validation loss decreased (0.377 --> 0.374).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 20/150 ==============================
# time: 93.85s   lr = 0.0001
#
# train average loss: 0.385  accuracy: 0.865
#
# valid average loss: 0.370  accuracy: 0.870
#
# ============================================================================
#
# Validation loss decreased (0.374 --> 0.370).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 21/150 ==============================
# time: 92.26s   lr = 0.0001
#
# train average loss: 0.375  accuracy: 0.869
#
# valid average loss: 0.365  accuracy: 0.875
#
# ============================================================================
#
# Validation loss decreased (0.370 --> 0.365).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 22/150 ==============================
# time: 93.35s   lr = 0.0001
#
# train average loss: 0.371  accuracy: 0.870
#
# valid average loss: 0.365  accuracy: 0.870
#
# ============================================================================
#
# Validation loss decreased (0.365 --> 0.365).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 23/150 ==============================
# time: 92.88s   lr = 0.0001
#
# train average loss: 0.371  accuracy: 0.872
#
# valid average loss: 0.366  accuracy: 0.873
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 24/150 ==============================
# time: 93.18s   lr = 0.0001
#
# train average loss: 0.368  accuracy: 0.872
#
# valid average loss: 0.358  accuracy: 0.877
#
# ============================================================================
#
# Validation loss decreased (0.365 --> 0.358).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 25/150 ==============================
# time: 93.13s   lr = 0.0001
#
# train average loss: 0.357  accuracy: 0.875
#
# valid average loss: 0.355  accuracy: 0.878
#
# ============================================================================
#
# Validation loss decreased (0.358 --> 0.355).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 26/150 ==============================
# time: 93.26s   lr = 0.0001
#
# train average loss: 0.359  accuracy: 0.873
#
# valid average loss: 0.349  accuracy: 0.879
#
# ============================================================================
#
# Validation loss decreased (0.355 --> 0.349).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 27/150 ==============================
# time: 92.57s   lr = 0.0001
#
# train average loss: 0.354  accuracy: 0.876
#
# valid average loss: 0.350  accuracy: 0.881
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 28/150 ==============================
# time: 92.86s   lr = 0.0001
#
# train average loss: 0.349  accuracy: 0.879
#
# valid average loss: 0.344  accuracy: 0.881
#
# ============================================================================
#
# Validation loss decreased (0.349 --> 0.344).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 29/150 ==============================
# time: 93.39s   lr = 0.0001
#
# train average loss: 0.343  accuracy: 0.879
#
# valid average loss: 0.343  accuracy: 0.881
#
# ============================================================================
#
# Validation loss decreased (0.344 --> 0.343).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 30/150 ==============================
# time: 92.30s   lr = 0.0001
#
# train average loss: 0.340  accuracy: 0.881
#
# valid average loss: 0.340  accuracy: 0.886
#
# ============================================================================
#
# Validation loss decreased (0.343 --> 0.340).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 31/150 ==============================
# time: 92.57s   lr = 0.0001
#
# train average loss: 0.335  accuracy: 0.884
#
# valid average loss: 0.344  accuracy: 0.882
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 32/150 ==============================
# time: 91.18s   lr = 0.0001
#
# train average loss: 0.331  accuracy: 0.884
#
# valid average loss: 0.341  accuracy: 0.883
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 33/150 ==============================
# time: 90.23s   lr = 0.0001
#
# train average loss: 0.331  accuracy: 0.883
#
# valid average loss: 0.334  accuracy: 0.884
#
# ============================================================================
#
# Validation loss decreased (0.340 --> 0.334).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 34/150 ==============================
# time: 89.57s   lr = 0.0001
#
# train average loss: 0.324  accuracy: 0.887
#
# valid average loss: 0.329  accuracy: 0.888
#
# ============================================================================
#
# Validation loss decreased (0.334 --> 0.329).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 35/150 ==============================
# time: 89.65s   lr = 0.0001
#
# train average loss: 0.322  accuracy: 0.886
#
# valid average loss: 0.331  accuracy: 0.887
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 36/150 ==============================
# time: 89.37s   lr = 0.0001
#
# train average loss: 0.318  accuracy: 0.889
#
# valid average loss: 0.331  accuracy: 0.883
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 37/150 ==============================
# time: 89.76s   lr = 0.0001
#
# train average loss: 0.317  accuracy: 0.888
#
# valid average loss: 0.328  accuracy: 0.884
#
# ============================================================================
#
# Validation loss decreased (0.329 --> 0.328).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 38/150 ==============================
# time: 89.96s   lr = 0.0001
#
# train average loss: 0.309  accuracy: 0.892
#
# valid average loss: 0.326  accuracy: 0.885
#
# ============================================================================
#
# Validation loss decreased (0.328 --> 0.326).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 39/150 ==============================
# time: 89.49s   lr = 0.0001
#
# train average loss: 0.314  accuracy: 0.889
#
# valid average loss: 0.326  accuracy: 0.888
#
# ============================================================================
#
# Validation loss decreased (0.326 --> 0.326).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 40/150 ==============================
# time: 89.59s   lr = 0.0001
#
# train average loss: 0.307  accuracy: 0.891
#
# valid average loss: 0.316  accuracy: 0.890
#
# ============================================================================
#
# Validation loss decreased (0.326 --> 0.316).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 41/150 ==============================
# time: 90.72s   lr = 0.0001
#
# train average loss: 0.304  accuracy: 0.894
#
# valid average loss: 0.316  accuracy: 0.894
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 42/150 ==============================
# time: 90.00s   lr = 0.0001
#
# train average loss: 0.300  accuracy: 0.894
#
# valid average loss: 0.322  accuracy: 0.890
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 43/150 ==============================
# time: 89.41s   lr = 0.0001
#
# train average loss: 0.299  accuracy: 0.895
#
# valid average loss: 0.315  accuracy: 0.891
#
# ============================================================================
#
# Validation loss decreased (0.316 --> 0.315).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 44/150 ==============================
# time: 90.28s   lr = 0.0001
#
# train average loss: 0.293  accuracy: 0.896
#
# valid average loss: 0.319  accuracy: 0.887
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 45/150 ==============================
# time: 90.86s   lr = 0.0001
#
# train average loss: 0.296  accuracy: 0.896
#
# valid average loss: 0.318  accuracy: 0.890
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 46/150 ==============================
# time: 90.26s   lr = 0.0001
#
# train average loss: 0.292  accuracy: 0.897
#
# valid average loss: 0.320  accuracy: 0.891
#
# ============================================================================
#
# EarlyStopping counter: 3 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 47/150 ==============================
# time: 91.54s   lr = 0.0001
#
# train average loss: 0.285  accuracy: 0.901
#
# valid average loss: 0.319  accuracy: 0.888
#
# ============================================================================
#
# EarlyStopping counter: 4 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 48/150 ==============================
# time: 91.86s   lr = 0.0001
#
# train average loss: 0.285  accuracy: 0.899
#
# valid average loss: 0.306  accuracy: 0.894
#
# ============================================================================
#
# Validation loss decreased (0.315 --> 0.306).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 49/150 ==============================
# time: 91.25s   lr = 0.0001
#
# train average loss: 0.281  accuracy: 0.902
#
# valid average loss: 0.311  accuracy: 0.891
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 50/150 ==============================
# time: 92.82s   lr = 0.0001
#
# train average loss: 0.282  accuracy: 0.901
#
# valid average loss: 0.308  accuracy: 0.897
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 51/150 ==============================
# time: 91.61s   lr = 0.0001
#
# train average loss: 0.275  accuracy: 0.901
#
# valid average loss: 0.311  accuracy: 0.895
#
# ============================================================================
#
# EarlyStopping counter: 3 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 52/150 ==============================
# time: 91.76s   lr = 0.0001
#
# train average loss: 0.277  accuracy: 0.903
#
# valid average loss: 0.307  accuracy: 0.895
#
# ============================================================================
#
# EarlyStopping counter: 4 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 53/150 ==============================
# time: 92.19s   lr = 0.0001
#
# train average loss: 0.274  accuracy: 0.904
#
# valid average loss: 0.307  accuracy: 0.893
#
# ============================================================================
#
# EarlyStopping counter: 5 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 54/150 ==============================
# time: 91.92s   lr = 0.0001
#
# train average loss: 0.269  accuracy: 0.907
#
# valid average loss: 0.305  accuracy: 0.897
#
# ============================================================================
#
# Validation loss decreased (0.306 --> 0.305).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 55/150 ==============================
# time: 92.73s   lr = 0.0001
#
# train average loss: 0.271  accuracy: 0.905
#
# valid average loss: 0.304  accuracy: 0.893
#
# ============================================================================
#
# Validation loss decreased (0.305 --> 0.304).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 56/150 ==============================
# time: 90.93s   lr = 0.0001
#
# train average loss: 0.269  accuracy: 0.906
#
# valid average loss: 0.307  accuracy: 0.894
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 57/150 ==============================
# time: 91.92s   lr = 0.0001
#
# train average loss: 0.265  accuracy: 0.905
#
# valid average loss: 0.303  accuracy: 0.895
#
# ============================================================================
#
# Validation loss decreased (0.304 --> 0.303).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 58/150 ==============================
# time: 91.48s   lr = 0.0001
#
# train average loss: 0.265  accuracy: 0.906
#
# valid average loss: 0.303  accuracy: 0.894
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 59/150 ==============================
# time: 92.56s   lr = 0.0001
#
# train average loss: 0.264  accuracy: 0.906
#
# valid average loss: 0.303  accuracy: 0.896
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 60/150 ==============================
# time: 91.18s   lr = 0.0001
#
# train average loss: 0.259  accuracy: 0.908
#
# valid average loss: 0.301  accuracy: 0.895
#
# ============================================================================
#
# Validation loss decreased (0.303 --> 0.301).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 61/150 ==============================
# time: 91.04s   lr = 0.0001
#
# train average loss: 0.257  accuracy: 0.910
#
# valid average loss: 0.292  accuracy: 0.899
#
# ============================================================================
#
# Validation loss decreased (0.301 --> 0.292).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 62/150 ==============================
# time: 91.16s   lr = 0.0001
#
# train average loss: 0.257  accuracy: 0.910
#
# valid average loss: 0.295  accuracy: 0.897
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 63/150 ==============================
# time: 92.07s   lr = 0.0001
#
# train average loss: 0.250  accuracy: 0.912
#
# valid average loss: 0.300  accuracy: 0.898
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 64/150 ==============================
# time: 91.89s   lr = 0.0001
#
# train average loss: 0.252  accuracy: 0.911
#
# valid average loss: 0.300  accuracy: 0.896
#
# ============================================================================
#
# EarlyStopping counter: 3 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 65/150 ==============================
# time: 91.29s   lr = 0.0001
#
# train average loss: 0.248  accuracy: 0.914
#
# valid average loss: 0.303  accuracy: 0.895
#
# ============================================================================
#
# EarlyStopping counter: 4 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 66/150 ==============================
# time: 91.93s   lr = 0.0001
#
# train average loss: 0.252  accuracy: 0.911
#
# valid average loss: 0.294  accuracy: 0.898
#
# ============================================================================
#
# EarlyStopping counter: 5 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 67/150 ==============================
# time: 91.46s   lr = 0.0001
#
# train average loss: 0.245  accuracy: 0.913
#
# valid average loss: 0.294  accuracy: 0.900
#
# ============================================================================
#
# EarlyStopping counter: 6 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 68/150 ==============================
# time: 92.41s   lr = 0.0001
#
# train average loss: 0.243  accuracy: 0.916
#
# valid average loss: 0.293  accuracy: 0.898
#
# ============================================================================
#
# EarlyStopping counter: 7 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 69/150 ==============================
# time: 92.30s   lr = 0.0001
#
# train average loss: 0.240  accuracy: 0.915
#
# valid average loss: 0.296  accuracy: 0.897
#
# ============================================================================
#
# EarlyStopping counter: 8 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 70/150 ==============================
# time: 92.35s   lr = 0.0001
#
# train average loss: 0.239  accuracy: 0.917
#
# valid average loss: 0.297  accuracy: 0.897
#
# ============================================================================
#
# EarlyStopping counter: 9 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 71/150 ==============================
# time: 92.35s   lr = 0.0001
#
# train average loss: 0.240  accuracy: 0.915
#
# valid average loss: 0.290  accuracy: 0.900
#
# ============================================================================
#
# Validation loss decreased (0.292 --> 0.290).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 72/150 ==============================
# time: 89.69s   lr = 0.0001
#
# train average loss: 0.238  accuracy: 0.916
#
# valid average loss: 0.296  accuracy: 0.899
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 73/150 ==============================
# time: 91.17s   lr = 0.0001
#
# train average loss: 0.235  accuracy: 0.916
#
# valid average loss: 0.294  accuracy: 0.897
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 74/150 ==============================
# time: 91.58s   lr = 0.0001
#
# train average loss: 0.235  accuracy: 0.917
#
# valid average loss: 0.292  accuracy: 0.901
#
# ============================================================================
#
# EarlyStopping counter: 3 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 75/150 ==============================
# time: 90.32s   lr = 0.0001
#
# train average loss: 0.231  accuracy: 0.919
#
# valid average loss: 0.300  accuracy: 0.900
#
# ============================================================================
#
# EarlyStopping counter: 4 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 76/150 ==============================
# time: 90.28s   lr = 0.0001
#
# train average loss: 0.230  accuracy: 0.920
#
# valid average loss: 0.289  accuracy: 0.901
#
# ============================================================================
#
# Validation loss decreased (0.290 --> 0.289).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 77/150 ==============================
# time: 90.52s   lr = 0.0001
#
# train average loss: 0.229  accuracy: 0.918
#
# valid average loss: 0.295  accuracy: 0.901
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 78/150 ==============================
# time: 91.26s   lr = 0.0001
#
# train average loss: 0.229  accuracy: 0.920
#
# valid average loss: 0.293  accuracy: 0.901
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 79/150 ==============================
# time: 91.66s   lr = 0.0001
#
# train average loss: 0.227  accuracy: 0.920
#
# valid average loss: 0.291  accuracy: 0.900
#
# ============================================================================
#
# EarlyStopping counter: 3 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 80/150 ==============================
# time: 91.61s   lr = 0.0001
#
# train average loss: 0.221  accuracy: 0.922
#
# valid average loss: 0.299  accuracy: 0.901
#
# ============================================================================
#
# EarlyStopping counter: 4 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 81/150 ==============================
# time: 90.19s   lr = 0.0001
#
# train average loss: 0.226  accuracy: 0.920
#
# valid average loss: 0.288  accuracy: 0.902
#
# ============================================================================
#
# Validation loss decreased (0.289 --> 0.288).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 82/150 ==============================
# time: 90.12s   lr = 0.0001
#
# train average loss: 0.222  accuracy: 0.922
#
# valid average loss: 0.286  accuracy: 0.902
#
# ============================================================================
#
# Validation loss decreased (0.288 --> 0.286).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 83/150 ==============================
# time: 89.86s   lr = 0.0001
#
# train average loss: 0.223  accuracy: 0.921
#
# valid average loss: 0.290  accuracy: 0.900
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 84/150 ==============================
# time: 90.96s   lr = 0.0001
#
# train average loss: 0.220  accuracy: 0.922
#
# valid average loss: 0.288  accuracy: 0.898
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 85/150 ==============================
# time: 90.31s   lr = 0.0001
#
# train average loss: 0.217  accuracy: 0.924
#
# valid average loss: 0.280  accuracy: 0.906
#
# ============================================================================
#
# Validation loss decreased (0.286 --> 0.280).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 86/150 ==============================
# time: 90.73s   lr = 0.0001
#
# train average loss: 0.216  accuracy: 0.924
#
# valid average loss: 0.293  accuracy: 0.900
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 87/150 ==============================
# time: 90.62s   lr = 0.0001
#
# train average loss: 0.215  accuracy: 0.924
#
# valid average loss: 0.281  accuracy: 0.905
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 88/150 ==============================
# time: 91.02s   lr = 0.0001
#
# train average loss: 0.213  accuracy: 0.925
#
# valid average loss: 0.282  accuracy: 0.904
#
# ============================================================================
#
# EarlyStopping counter: 3 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 89/150 ==============================
# time: 91.77s   lr = 0.0001
#
# train average loss: 0.214  accuracy: 0.924
#
# valid average loss: 0.285  accuracy: 0.901
#
# ============================================================================
#
# EarlyStopping counter: 4 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 90/150 ==============================
# time: 91.33s   lr = 0.0001
#
# train average loss: 0.214  accuracy: 0.925
#
# valid average loss: 0.279  accuracy: 0.904
#
# ============================================================================
#
# Validation loss decreased (0.280 --> 0.279).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 91/150 ==============================
# time: 92.19s   lr = 0.0001
#
# train average loss: 0.209  accuracy: 0.927
#
# valid average loss: 0.280  accuracy: 0.905
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 92/150 ==============================
# time: 91.09s   lr = 0.0001
#
# train average loss: 0.208  accuracy: 0.926
#
# valid average loss: 0.280  accuracy: 0.906
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 93/150 ==============================
# time: 92.01s   lr = 0.0001
#
# train average loss: 0.208  accuracy: 0.926
#
# valid average loss: 0.288  accuracy: 0.902
#
# ============================================================================
#
# EarlyStopping counter: 3 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 94/150 ==============================
# time: 91.81s   lr = 0.0001
#
# train average loss: 0.211  accuracy: 0.924
#
# valid average loss: 0.280  accuracy: 0.906
#
# ============================================================================
#
# EarlyStopping counter: 4 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 95/150 ==============================
# time: 91.37s   lr = 0.0001
#
# train average loss: 0.201  accuracy: 0.929
#
# valid average loss: 0.279  accuracy: 0.905
#
# ============================================================================
#
# EarlyStopping counter: 5 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 96/150 ==============================
# time: 91.40s   lr = 0.0001
#
# train average loss: 0.204  accuracy: 0.926
#
# valid average loss: 0.285  accuracy: 0.902
#
# ============================================================================
#
# EarlyStopping counter: 6 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 97/150 ==============================
# time: 91.83s   lr = 0.0001
#
# train average loss: 0.203  accuracy: 0.929
#
# valid average loss: 0.284  accuracy: 0.902
#
# ============================================================================
#
# EarlyStopping counter: 7 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 98/150 ==============================
# time: 91.03s   lr = 0.0001
#
# train average loss: 0.201  accuracy: 0.928
#
# valid average loss: 0.287  accuracy: 0.902
#
# ============================================================================
#
# EarlyStopping counter: 8 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 99/150 ==============================
# time: 91.61s   lr = 0.0001
#
# train average loss: 0.201  accuracy: 0.929
#
# valid average loss: 0.280  accuracy: 0.904
#
# ============================================================================
#
# EarlyStopping counter: 9 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 100/150 ==============================
# time: 90.77s   lr = 0.0001
#
# train average loss: 0.201  accuracy: 0.930
#
# valid average loss: 0.275  accuracy: 0.908
#
# ============================================================================
#
# Validation loss decreased (0.279 --> 0.275).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 101/150 ==============================
# time: 91.51s   lr = 0.0001
#
# train average loss: 0.201  accuracy: 0.928
#
# valid average loss: 0.279  accuracy: 0.906
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 102/150 ==============================
# time: 91.67s   lr = 0.0001
#
# train average loss: 0.196  accuracy: 0.931
#
# valid average loss: 0.281  accuracy: 0.905
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 103/150 ==============================
# time: 91.87s   lr = 0.0001
#
# train average loss: 0.198  accuracy: 0.930
#
# valid average loss: 0.282  accuracy: 0.903
#
# ============================================================================
#
# EarlyStopping counter: 3 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 104/150 ==============================
# time: 91.10s   lr = 0.0001
#
# train average loss: 0.197  accuracy: 0.930
#
# valid average loss: 0.280  accuracy: 0.907
#
# ============================================================================
#
# EarlyStopping counter: 4 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 105/150 ==============================
# time: 91.27s   lr = 0.0001
#
# train average loss: 0.196  accuracy: 0.930
#
# valid average loss: 0.275  accuracy: 0.908
#
# ============================================================================
#
# Validation loss decreased (0.275 --> 0.275).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 106/150 ==============================
# time: 91.34s   lr = 0.0001
#
# train average loss: 0.192  accuracy: 0.933
#
# valid average loss: 0.275  accuracy: 0.910
#
# ============================================================================
#
# Validation loss decreased (0.275 --> 0.275).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 107/150 ==============================
# time: 90.18s   lr = 0.0001
#
# train average loss: 0.194  accuracy: 0.931
#
# valid average loss: 0.273  accuracy: 0.906
#
# ============================================================================
#
# Validation loss decreased (0.275 --> 0.273).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 108/150 ==============================
# time: 90.30s   lr = 0.0001
#
# train average loss: 0.189  accuracy: 0.933
#
# valid average loss: 0.278  accuracy: 0.905
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 109/150 ==============================
# time: 91.28s   lr = 0.0001
#
# train average loss: 0.187  accuracy: 0.934
#
# valid average loss: 0.279  accuracy: 0.906
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 110/150 ==============================
# time: 89.99s   lr = 0.0001
#
# train average loss: 0.190  accuracy: 0.932
#
# valid average loss: 0.277  accuracy: 0.905
#
# ============================================================================
#
# EarlyStopping counter: 3 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 111/150 ==============================
# time: 89.05s   lr = 0.0001
#
# train average loss: 0.185  accuracy: 0.935
#
# valid average loss: 0.280  accuracy: 0.906
#
# ============================================================================
#
# EarlyStopping counter: 4 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 112/150 ==============================
# time: 89.11s   lr = 0.0001
#
# train average loss: 0.184  accuracy: 0.935
#
# valid average loss: 0.281  accuracy: 0.905
#
# ============================================================================
#
# EarlyStopping counter: 5 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 113/150 ==============================
# time: 89.23s   lr = 0.0001
#
# train average loss: 0.184  accuracy: 0.935
#
# valid average loss: 0.271  accuracy: 0.910
#
# ============================================================================
#
# Validation loss decreased (0.273 --> 0.271).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 114/150 ==============================
# time: 88.76s   lr = 0.0001
#
# train average loss: 0.184  accuracy: 0.935
#
# valid average loss: 0.281  accuracy: 0.907
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 115/150 ==============================
# time: 89.37s   lr = 0.0001
#
# train average loss: 0.185  accuracy: 0.933
#
# valid average loss: 0.287  accuracy: 0.904
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 116/150 ==============================
# time: 89.30s   lr = 0.0001
#
# train average loss: 0.182  accuracy: 0.936
#
# valid average loss: 0.278  accuracy: 0.906
#
# ============================================================================
#
# EarlyStopping counter: 3 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 117/150 ==============================
# time: 89.13s   lr = 0.0001
#
# train average loss: 0.181  accuracy: 0.936
#
# valid average loss: 0.283  accuracy: 0.906
#
# ============================================================================
#
# EarlyStopping counter: 4 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 118/150 ==============================
# time: 89.94s   lr = 0.0001
#
# train average loss: 0.178  accuracy: 0.937
#
# valid average loss: 0.278  accuracy: 0.908
#
# ============================================================================
#
# EarlyStopping counter: 5 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 119/150 ==============================
# time: 89.70s   lr = 0.0001
#
# train average loss: 0.180  accuracy: 0.936
#
# valid average loss: 0.284  accuracy: 0.903
#
# ============================================================================
#
# EarlyStopping counter: 6 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 120/150 ==============================
# time: 89.06s   lr = 0.0001
#
# train average loss: 0.180  accuracy: 0.936
#
# valid average loss: 0.277  accuracy: 0.907
#
# ============================================================================
#
# EarlyStopping counter: 7 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 121/150 ==============================
# time: 89.84s   lr = 0.0001
#
# train average loss: 0.177  accuracy: 0.938
#
# valid average loss: 0.269  accuracy: 0.911
#
# ============================================================================
#
# Validation loss decreased (0.271 --> 0.269).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 122/150 ==============================
# time: 89.19s   lr = 0.0001
#
# train average loss: 0.180  accuracy: 0.937
#
# valid average loss: 0.277  accuracy: 0.909
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 123/150 ==============================
# time: 88.86s   lr = 0.0001
#
# train average loss: 0.174  accuracy: 0.938
#
# valid average loss: 0.277  accuracy: 0.905
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 124/150 ==============================
# time: 89.75s   lr = 0.0001
#
# train average loss: 0.175  accuracy: 0.938
#
# valid average loss: 0.276  accuracy: 0.907
#
# ============================================================================
#
# EarlyStopping counter: 3 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 125/150 ==============================
# time: 89.78s   lr = 0.0001
#
# train average loss: 0.171  accuracy: 0.938
#
# valid average loss: 0.279  accuracy: 0.907
#
# ============================================================================
#
# EarlyStopping counter: 4 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 126/150 ==============================
# time: 90.13s   lr = 0.0001
#
# train average loss: 0.171  accuracy: 0.940
#
# valid average loss: 0.271  accuracy: 0.908
#
# ============================================================================
#
# EarlyStopping counter: 5 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 127/150 ==============================
# time: 90.06s   lr = 0.0001
#
# train average loss: 0.172  accuracy: 0.939
#
# valid average loss: 0.270  accuracy: 0.912
#
# ============================================================================
#
# EarlyStopping counter: 6 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 128/150 ==============================
# time: 89.48s   lr = 0.0001
#
# train average loss: 0.170  accuracy: 0.941
#
# valid average loss: 0.283  accuracy: 0.904
#
# ============================================================================
#
# EarlyStopping counter: 7 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 129/150 ==============================
# time: 89.38s   lr = 0.0001
#
# train average loss: 0.168  accuracy: 0.940
#
# valid average loss: 0.280  accuracy: 0.907
#
# ============================================================================
#
# EarlyStopping counter: 8 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 130/150 ==============================
# time: 89.53s   lr = 0.0001
#
# train average loss: 0.166  accuracy: 0.942
#
# valid average loss: 0.282  accuracy: 0.906
#
# ============================================================================
#
# EarlyStopping counter: 9 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 131/150 ==============================
# time: 89.53s   lr = 0.0001
#
# train average loss: 0.168  accuracy: 0.942
#
# valid average loss: 0.275  accuracy: 0.909
#
# ============================================================================
#
# EarlyStopping counter: 10 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 132/150 ==============================
# time: 90.23s   lr = 0.0001
#
# train average loss: 0.168  accuracy: 0.940
#
# valid average loss: 0.278  accuracy: 0.907
#
# ============================================================================
# Epoch 00132: reducing learning rate of group 0 to 1.0000e-05.
#
# EarlyStopping counter: 11 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 133/150 ==============================
# time: 90.16s   lr = 1e-05
#
# train average loss: 0.160  accuracy: 0.945
#
# valid average loss: 0.272  accuracy: 0.909
#
# ============================================================================
#
# EarlyStopping counter: 12 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 134/150 ==============================
# time: 89.78s   lr = 1e-05
#
# train average loss: 0.157  accuracy: 0.945
#
# valid average loss: 0.266  accuracy: 0.914
#
# ============================================================================
#
# Validation loss decreased (0.269 --> 0.266).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 135/150 ==============================
# time: 89.33s   lr = 1e-05
#
# train average loss: 0.159  accuracy: 0.945
#
# valid average loss: 0.266  accuracy: 0.912
#
# ============================================================================
#
# Validation loss decreased (0.266 --> 0.266).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 136/150 ==============================
# time: 89.87s   lr = 1e-05
#
# train average loss: 0.160  accuracy: 0.945
#
# valid average loss: 0.271  accuracy: 0.910
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 137/150 ==============================
# time: 89.69s   lr = 1e-05
#
# train average loss: 0.157  accuracy: 0.945
#
# valid average loss: 0.271  accuracy: 0.910
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 138/150 ==============================
# time: 90.17s   lr = 1e-05
#
# train average loss: 0.155  accuracy: 0.945
#
# valid average loss: 0.269  accuracy: 0.911
#
# ============================================================================
#
# EarlyStopping counter: 3 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 139/150 ==============================
# time: 89.07s   lr = 1e-05
#
# train average loss: 0.158  accuracy: 0.945
#
# valid average loss: 0.273  accuracy: 0.911
#
# ============================================================================
#
# EarlyStopping counter: 4 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 140/150 ==============================
# time: 89.82s   lr = 1e-05
#
# train average loss: 0.158  accuracy: 0.944
#
# valid average loss: 0.265  accuracy: 0.912
#
# ============================================================================
#
# Validation loss decreased (0.266 --> 0.265).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 141/150 ==============================
# time: 89.00s   lr = 1e-05
#
# train average loss: 0.159  accuracy: 0.943
#
# valid average loss: 0.273  accuracy: 0.911
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 142/150 ==============================
# time: 88.93s   lr = 1e-05
#
# train average loss: 0.158  accuracy: 0.944
#
# valid average loss: 0.263  accuracy: 0.914
#
# ============================================================================
#
# Validation loss decreased (0.265 --> 0.263).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 143/150 ==============================
# time: 88.97s   lr = 1e-05
#
# train average loss: 0.160  accuracy: 0.944
#
# valid average loss: 0.269  accuracy: 0.910
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 144/150 ==============================
# time: 88.91s   lr = 1e-05
#
# train average loss: 0.158  accuracy: 0.944
#
# valid average loss: 0.273  accuracy: 0.908
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 145/150 ==============================
# time: 88.69s   lr = 1e-05
#
# train average loss: 0.159  accuracy: 0.944
#
# valid average loss: 0.269  accuracy: 0.910
#
# ============================================================================
#
# EarlyStopping counter: 3 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 146/150 ==============================
# time: 89.63s   lr = 1e-05
#
# train average loss: 0.156  accuracy: 0.944
#
# valid average loss: 0.273  accuracy: 0.910
#
# ============================================================================
#
# EarlyStopping counter: 4 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 147/150 ==============================
# time: 89.30s   lr = 1e-05
#
# train average loss: 0.159  accuracy: 0.944
#
# valid average loss: 0.278  accuracy: 0.907
#
# ============================================================================
#
# EarlyStopping counter: 5 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 148/150 ==============================
# time: 89.70s   lr = 1e-05
#
# train average loss: 0.157  accuracy: 0.944
#
# valid average loss: 0.276  accuracy: 0.909
#
# ============================================================================
#
# EarlyStopping counter: 6 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 149/150 ==============================
# time: 90.21s   lr = 1e-05
#
# train average loss: 0.155  accuracy: 0.946
#
# valid average loss: 0.274  accuracy: 0.910
#
# ============================================================================
#
# EarlyStopping counter: 7 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 150/150 ==============================
# time: 89.62s   lr = 1e-05
#
# train average loss: 0.157  accuracy: 0.944
#
# valid average loss: 0.272  accuracy: 0.909
#
# ============================================================================
#
# EarlyStopping counter: 8 out of 15
#
# Total time for training is 1.4e+04s

# %%
# case 5: dropout rate 0.1
dropout01_alexnet = AlexNet(num_classes=10, dropout=0.1)
summary(dropout01_alexnet, (3, 224, 224), device='cpu')

case5_model = TrainModel(
    model=dropout01_alexnet,
    lr=1e-2,
    epochs=90,
    train_log_step=1000,
    valid_log_step=300,
    early_stop=True,
    es_path='dropout01_alexnet.pt',
)

history5 = case5_model.fit(train_loader, valid_loader)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 55, 55]          23,296
#               ReLU-2           [-1, 64, 55, 55]               0
#          MaxPool2d-3           [-1, 64, 27, 27]               0
#             Conv2d-4          [-1, 192, 27, 27]         307,392
#               ReLU-5          [-1, 192, 27, 27]               0
#          MaxPool2d-6          [-1, 192, 13, 13]               0
#             Conv2d-7          [-1, 384, 13, 13]         663,936
#               ReLU-8          [-1, 384, 13, 13]               0
#             Conv2d-9          [-1, 256, 13, 13]         884,992
#              ReLU-10          [-1, 256, 13, 13]               0
#            Conv2d-11          [-1, 256, 13, 13]         590,080
#              ReLU-12          [-1, 256, 13, 13]               0
#         MaxPool2d-13            [-1, 256, 6, 6]               0
# AdaptiveAvgPool2d-14            [-1, 256, 6, 6]               0
#           Dropout-15                 [-1, 9216]               0
#            Linear-16                 [-1, 4096]      37,752,832
#              ReLU-17                 [-1, 4096]               0
#           Dropout-18                 [-1, 4096]               0
#            Linear-19                 [-1, 4096]      16,781,312
#              ReLU-20                 [-1, 4096]               0
#            Linear-21                   [-1, 10]          40,970
#           AlexNet-22                   [-1, 10]               0
# ================================================================
# Total params: 57,044,810
# Trainable params: 57,044,810
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 8.37
# Params size (MB): 217.61
# Estimated Total Size (MB): 226.55
# ----------------------------------------------------------------
# Single GPU training!
# Start Model Training...!
#   0%|          | 0/90 [00:00<?, ?it/s]
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 1/90 ==============================
# time: 82.93s   lr = 0.01
#
# train average loss: 0.760  accuracy: 0.736
#
# valid average loss: 0.576  accuracy: 0.798
#
# ============================================================================
#
# Validation loss decreased (inf --> 0.576).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 2/90 ==============================
# time: 82.20s   lr = 0.01
#
# train average loss: 0.464  accuracy: 0.839
#
# valid average loss: 0.487  accuracy: 0.832
#
# ============================================================================
#
# Validation loss decreased (0.576 --> 0.487).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 3/90 ==============================
# time: 83.11s   lr = 0.01
#
# train average loss: 0.363  accuracy: 0.874
#
# valid average loss: 0.427  accuracy: 0.852
#
# ============================================================================
#
# Validation loss decreased (0.487 --> 0.427).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 4/90 ==============================
# time: 83.24s   lr = 0.01
#
# train average loss: 0.305  accuracy: 0.894
#
# valid average loss: 0.387  accuracy: 0.867
#
# ============================================================================
#
# Validation loss decreased (0.427 --> 0.387).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 5/90 ==============================
# time: 82.71s   lr = 0.01
#
# train average loss: 0.248  accuracy: 0.913
#
# valid average loss: 0.365  accuracy: 0.875
#
# ============================================================================
#
# Validation loss decreased (0.387 --> 0.365).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 6/90 ==============================
# time: 82.83s   lr = 0.01
#
# train average loss: 0.208  accuracy: 0.927
#
# valid average loss: 0.440  accuracy: 0.859
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 7/90 ==============================
# time: 82.70s   lr = 0.01
#
# train average loss: 0.187  accuracy: 0.934
#
# valid average loss: 0.383  accuracy: 0.876
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 8/90 ==============================
# time: 82.41s   lr = 0.01
#
# train average loss: 0.161  accuracy: 0.944
#
# valid average loss: 0.366  accuracy: 0.880
#
# ============================================================================
#
# EarlyStopping counter: 3 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 9/90 ==============================
# time: 82.84s   lr = 0.01
#
# train average loss: 0.136  accuracy: 0.952
#
# valid average loss: 0.370  accuracy: 0.881
#
# ============================================================================
#
# EarlyStopping counter: 4 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 10/90 ==============================
# time: 82.86s   lr = 0.01
#
# train average loss: 0.129  accuracy: 0.955
#
# valid average loss: 0.389  accuracy: 0.880
#
# ============================================================================
#
# EarlyStopping counter: 5 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 11/90 ==============================
# time: 82.39s   lr = 0.01
#
# train average loss: 0.107  accuracy: 0.963
#
# valid average loss: 0.378  accuracy: 0.890
#
# ============================================================================
#
# EarlyStopping counter: 6 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 12/90 ==============================
# time: 82.89s   lr = 0.01
#
# train average loss: 0.102  accuracy: 0.966
#
# valid average loss: 0.379  accuracy: 0.883
#
# ============================================================================
#
# EarlyStopping counter: 7 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 13/90 ==============================
# time: 82.92s   lr = 0.01
#
# train average loss: 0.091  accuracy: 0.969
#
# valid average loss: 0.377  accuracy: 0.889
#
# ============================================================================
#
# EarlyStopping counter: 8 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 14/90 ==============================
# time: 82.21s   lr = 0.01
#
# train average loss: 0.077  accuracy: 0.973
#
# valid average loss: 0.397  accuracy: 0.893
#
# ============================================================================
#
# EarlyStopping counter: 9 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 15/90 ==============================
# time: 82.80s   lr = 0.01
#
# train average loss: 0.075  accuracy: 0.975
#
# valid average loss: 0.377  accuracy: 0.890
#
# ============================================================================
#
# EarlyStopping counter: 10 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 16/90 ==============================
# time: 83.36s   lr = 0.01
#
# train average loss: 0.063  accuracy: 0.979
#
# valid average loss: 0.368  accuracy: 0.890
#
# ============================================================================
# Epoch 00016: reducing learning rate of group 0 to 1.0000e-03.
#
# EarlyStopping counter: 11 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 17/90 ==============================
# time: 82.70s   lr = 0.001
#
# train average loss: 0.023  accuracy: 0.994
#
# valid average loss: 0.323  accuracy: 0.913
#
# ============================================================================
#
# Validation loss decreased (0.365 --> 0.323).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 18/90 ==============================
# time: 101.84s   lr = 0.001
#
# train average loss: 0.015  accuracy: 0.996
#
# valid average loss: 0.350  accuracy: 0.910
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 19/90 ==============================
# time: 102.04s   lr = 0.001
#
# train average loss: 0.013  accuracy: 0.996
#
# valid average loss: 0.334  accuracy: 0.915
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 20/90 ==============================
# time: 102.11s   lr = 0.001
#
# train average loss: 0.011  accuracy: 0.997
#
# valid average loss: 0.338  accuracy: 0.916
#
# ============================================================================
#
# EarlyStopping counter: 3 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 21/90 ==============================
# time: 102.37s   lr = 0.001
#
# train average loss: 0.010  accuracy: 0.997
#
# valid average loss: 0.363  accuracy: 0.910
#
# ============================================================================
#
# EarlyStopping counter: 4 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 22/90 ==============================
# time: 101.62s   lr = 0.001
#
# train average loss: 0.008  accuracy: 0.998
#
# valid average loss: 0.359  accuracy: 0.913
#
# ============================================================================
#
# EarlyStopping counter: 5 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 23/90 ==============================
# time: 102.57s   lr = 0.001
#
# train average loss: 0.008  accuracy: 0.998
#
# valid average loss: 0.357  accuracy: 0.913
#
# ============================================================================
#
# EarlyStopping counter: 6 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 24/90 ==============================
# time: 103.02s   lr = 0.001
#
# train average loss: 0.007  accuracy: 0.998
#
# valid average loss: 0.369  accuracy: 0.911
#
# ============================================================================
#
# EarlyStopping counter: 7 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 25/90 ==============================
# time: 103.29s   lr = 0.001
#
# train average loss: 0.007  accuracy: 0.998
#
# valid average loss: 0.368  accuracy: 0.910
#
# ============================================================================
#
# EarlyStopping counter: 8 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 26/90 ==============================
# time: 102.23s   lr = 0.001
#
# train average loss: 0.006  accuracy: 0.998
#
# valid average loss: 0.363  accuracy: 0.914
#
# ============================================================================
#
# EarlyStopping counter: 9 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 27/90 ==============================
# time: 102.57s   lr = 0.001
#
# train average loss: 0.007  accuracy: 0.998
#
# valid average loss: 0.369  accuracy: 0.915
#
# ============================================================================
#
# EarlyStopping counter: 10 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 28/90 ==============================
# time: 101.94s   lr = 0.001
#
# train average loss: 0.007  accuracy: 0.998
#
# valid average loss: 0.373  accuracy: 0.913
#
# ============================================================================
# Epoch 00028: reducing learning rate of group 0 to 1.0000e-04.
#
# EarlyStopping counter: 11 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 29/90 ==============================
# time: 102.27s   lr = 0.0001
#
# train average loss: 0.006  accuracy: 0.999
#
# valid average loss: 0.360  accuracy: 0.916
#
# ============================================================================
#
# EarlyStopping counter: 12 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 30/90 ==============================
# time: 102.66s   lr = 0.0001
#
# train average loss: 0.006  accuracy: 0.999
#
# valid average loss: 0.370  accuracy: 0.915
#
# ============================================================================
#
# EarlyStopping counter: 13 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 31/90 ==============================
# time: 101.98s   lr = 0.0001
#
# train average loss: 0.006  accuracy: 0.998
#
# valid average loss: 0.363  accuracy: 0.915
#
# ============================================================================
#
# EarlyStopping counter: 14 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 32/90 ==============================
# time: 102.42s   lr = 0.0001
#
# train average loss: 0.005  accuracy: 0.999
#
# valid average loss: 0.367  accuracy: 0.917
#
# ============================================================================
#
# EarlyStopping counter: 15 out of 15
#
# ##########################
# ##### Early Stopping #####
# ##########################
#
# Total time for training is 2.9e+03s

# %%
# case 6: remove one convolution layer
del_conv_alexnet = AlexNet(num_classes=10)
summary(del_conv_alexnet, (3, 224, 224), device='cpu')

case6_model = TrainModel(
    model=del_conv_alexnet,
    lr=1e-2,
    epochs=90,
    train_log_step=1000,
    valid_log_step=300,
    early_stop=True,
    es_path='del_conv_alexnet.pt'
)

history6 = case6_model.fit(train_loader, valid_loader)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 55, 55]          23,296
#               ReLU-2           [-1, 64, 55, 55]               0
#          MaxPool2d-3           [-1, 64, 27, 27]               0
#             Conv2d-4          [-1, 192, 27, 27]         307,392
#               ReLU-5          [-1, 192, 27, 27]               0
#          MaxPool2d-6          [-1, 192, 13, 13]               0
#             Conv2d-7          [-1, 384, 13, 13]         663,936
#               ReLU-8          [-1, 384, 13, 13]               0
#             Conv2d-9          [-1, 256, 13, 13]         884,992
#              ReLU-10          [-1, 256, 13, 13]               0
#            Conv2d-11          [-1, 256, 13, 13]         590,080
#              ReLU-12          [-1, 256, 13, 13]               0
#         MaxPool2d-13            [-1, 256, 6, 6]               0
# AdaptiveAvgPool2d-14            [-1, 256, 6, 6]               0
#           Dropout-15                 [-1, 9216]               0
#            Linear-16                 [-1, 4096]      37,752,832
#              ReLU-17                 [-1, 4096]               0
#           Dropout-18                 [-1, 4096]               0
#            Linear-19                 [-1, 4096]      16,781,312
#              ReLU-20                 [-1, 4096]               0
#            Linear-21                   [-1, 10]          40,970
#           AlexNet-22                   [-1, 10]               0
# ================================================================
# Total params: 57,044,810
# Trainable params: 57,044,810
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 8.37
# Params size (MB): 217.61
# Estimated Total Size (MB): 226.55
# ----------------------------------------------------------------
# Single GPU training!
# Start Model Training...!
#   0%|          | 0/90 [00:00<?, ?it/s]
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 1/90 ==============================
# time: 103.06s   lr = 0.01
#
# train average loss: 0.831  accuracy: 0.710
#
# valid average loss: 0.557  accuracy: 0.808
#
# ============================================================================
#
# Validation loss decreased (inf --> 0.557).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 2/90 ==============================
# time: 102.69s   lr = 0.01
#
# train average loss: 0.545  accuracy: 0.812
#
# valid average loss: 0.498  accuracy: 0.823
#
# ============================================================================
#
# Validation loss decreased (0.557 --> 0.498).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 3/90 ==============================
# time: 101.65s   lr = 0.01
#
# train average loss: 0.465  accuracy: 0.838
#
# valid average loss: 0.426  accuracy: 0.852
#
# ============================================================================
#
# Validation loss decreased (0.498 --> 0.426).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 4/90 ==============================
# time: 102.10s   lr = 0.01
#
# train average loss: 0.399  accuracy: 0.860
#
# valid average loss: 0.370  accuracy: 0.871
#
# ============================================================================
#
# Validation loss decreased (0.426 --> 0.370).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 5/90 ==============================
# time: 102.25s   lr = 0.01
#
# train average loss: 0.351  accuracy: 0.879
#
# valid average loss: 0.395  accuracy: 0.864
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 6/90 ==============================
# time: 102.59s   lr = 0.01
#
# train average loss: 0.316  accuracy: 0.891
#
# valid average loss: 0.397  accuracy: 0.863
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 7/90 ==============================
# time: 101.75s   lr = 0.01
#
# train average loss: 0.293  accuracy: 0.897
#
# valid average loss: 0.365  accuracy: 0.876
#
# ============================================================================
#
# Validation loss decreased (0.370 --> 0.365).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 8/90 ==============================
# time: 102.01s   lr = 0.01
#
# train average loss: 0.272  accuracy: 0.905
#
# valid average loss: 0.353  accuracy: 0.882
#
# ============================================================================
#
# Validation loss decreased (0.365 --> 0.353).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 9/90 ==============================
# time: 101.97s   lr = 0.01
#
# train average loss: 0.254  accuracy: 0.911
#
# valid average loss: 0.371  accuracy: 0.876
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 10/90 ==============================
# time: 101.99s   lr = 0.01
#
# train average loss: 0.237  accuracy: 0.916
#
# valid average loss: 0.331  accuracy: 0.887
#
# ============================================================================
#
# Validation loss decreased (0.353 --> 0.331).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 11/90 ==============================
# time: 101.75s   lr = 0.01
#
# train average loss: 0.223  accuracy: 0.922
#
# valid average loss: 0.320  accuracy: 0.894
#
# ============================================================================
#
# Validation loss decreased (0.331 --> 0.320).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 12/90 ==============================
# time: 102.28s   lr = 0.01
#
# train average loss: 0.197  accuracy: 0.931
#
# valid average loss: 0.331  accuracy: 0.888
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 13/90 ==============================
# time: 102.10s   lr = 0.01
#
# train average loss: 0.187  accuracy: 0.935
#
# valid average loss: 0.340  accuracy: 0.892
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 14/90 ==============================
# time: 102.21s   lr = 0.01
#
# train average loss: 0.185  accuracy: 0.936
#
# valid average loss: 0.326  accuracy: 0.890
#
# ============================================================================
#
# EarlyStopping counter: 3 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 15/90 ==============================
# time: 102.41s   lr = 0.01
#
# train average loss: 0.170  accuracy: 0.940
#
# valid average loss: 0.314  accuracy: 0.895
#
# ============================================================================
#
# Validation loss decreased (0.320 --> 0.314).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 16/90 ==============================
# time: 101.77s   lr = 0.01
#
# train average loss: 0.166  accuracy: 0.943
#
# valid average loss: 0.329  accuracy: 0.896
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 17/90 ==============================
# time: 102.63s   lr = 0.01
#
# train average loss: 0.152  accuracy: 0.946
#
# valid average loss: 0.337  accuracy: 0.889
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 18/90 ==============================
# time: 102.09s   lr = 0.01
#
# train average loss: 0.143  accuracy: 0.950
#
# valid average loss: 0.323  accuracy: 0.899
#
# ============================================================================
#
# EarlyStopping counter: 3 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 19/90 ==============================
# time: 102.40s   lr = 0.01
#
# train average loss: 0.140  accuracy: 0.952
#
# valid average loss: 0.355  accuracy: 0.890
#
# ============================================================================
#
# EarlyStopping counter: 4 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 20/90 ==============================
# time: 102.33s   lr = 0.01
#
# train average loss: 0.148  accuracy: 0.947
#
# valid average loss: 0.322  accuracy: 0.897
#
# ============================================================================
#
# EarlyStopping counter: 5 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 21/90 ==============================
# time: 102.81s   lr = 0.01
#
# train average loss: 0.127  accuracy: 0.957
#
# valid average loss: 0.337  accuracy: 0.894
#
# ============================================================================
#
# EarlyStopping counter: 6 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 22/90 ==============================
# time: 102.32s   lr = 0.01
#
# train average loss: 0.118  accuracy: 0.959
#
# valid average loss: 0.355  accuracy: 0.893
#
# ============================================================================
#
# EarlyStopping counter: 7 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 23/90 ==============================
# time: 102.44s   lr = 0.01
#
# train average loss: 0.118  accuracy: 0.959
#
# valid average loss: 0.317  accuracy: 0.900
#
# ============================================================================
#
# EarlyStopping counter: 8 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 24/90 ==============================
# time: 101.97s   lr = 0.01
#
# train average loss: 0.115  accuracy: 0.961
#
# valid average loss: 0.357  accuracy: 0.895
#
# ============================================================================
#
# EarlyStopping counter: 9 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 25/90 ==============================
# time: 102.95s   lr = 0.01
#
# train average loss: 0.115  accuracy: 0.960
#
# valid average loss: 0.334  accuracy: 0.901
#
# ============================================================================
#
# EarlyStopping counter: 10 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 26/90 ==============================
# time: 102.74s   lr = 0.01
#
# train average loss: 0.110  accuracy: 0.962
#
# valid average loss: 0.343  accuracy: 0.896
#
# ============================================================================
# Epoch 00026: reducing learning rate of group 0 to 1.0000e-03.
#
# EarlyStopping counter: 11 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 27/90 ==============================
# time: 103.41s   lr = 0.001
#
# train average loss: 0.052  accuracy: 0.983
#
# valid average loss: 0.283  accuracy: 0.917
#
# ============================================================================
#
# Validation loss decreased (0.314 --> 0.283).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 28/90 ==============================
# time: 102.20s   lr = 0.001
#
# train average loss: 0.040  accuracy: 0.987
#
# valid average loss: 0.286  accuracy: 0.919
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 29/90 ==============================
# time: 103.07s   lr = 0.001
#
# train average loss: 0.036  accuracy: 0.988
#
# valid average loss: 0.284  accuracy: 0.919
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 30/90 ==============================
# time: 102.94s   lr = 0.001
#
# train average loss: 0.032  accuracy: 0.989
#
# valid average loss: 0.284  accuracy: 0.921
#
# ============================================================================
#
# EarlyStopping counter: 3 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 31/90 ==============================
# time: 102.58s   lr = 0.001
#
# train average loss: 0.032  accuracy: 0.990
#
# valid average loss: 0.301  accuracy: 0.918
#
# ============================================================================
#
# EarlyStopping counter: 4 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 32/90 ==============================
# time: 102.23s   lr = 0.001
#
# train average loss: 0.029  accuracy: 0.991
#
# valid average loss: 0.296  accuracy: 0.919
#
# ============================================================================
#
# EarlyStopping counter: 5 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 33/90 ==============================
# time: 102.52s   lr = 0.001
#
# train average loss: 0.029  accuracy: 0.991
#
# valid average loss: 0.302  accuracy: 0.919
#
# ============================================================================
#
# EarlyStopping counter: 6 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 34/90 ==============================
# time: 102.45s   lr = 0.001
#
# train average loss: 0.029  accuracy: 0.991
#
# valid average loss: 0.293  accuracy: 0.921
#
# ============================================================================
#
# EarlyStopping counter: 7 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 35/90 ==============================
# time: 102.48s   lr = 0.001
#
# train average loss: 0.025  accuracy: 0.992
#
# valid average loss: 0.281  accuracy: 0.926
#
# ============================================================================
#
# Validation loss decreased (0.283 --> 0.281).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 36/90 ==============================
# time: 102.41s   lr = 0.001
#
# train average loss: 0.025  accuracy: 0.992
#
# valid average loss: 0.292  accuracy: 0.919
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 37/90 ==============================
# time: 102.99s   lr = 0.001
#
# train average loss: 0.024  accuracy: 0.993
#
# valid average loss: 0.297  accuracy: 0.922
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 38/90 ==============================
# time: 103.03s   lr = 0.001
#
# train average loss: 0.022  accuracy: 0.993
#
# valid average loss: 0.298  accuracy: 0.922
#
# ============================================================================
#
# EarlyStopping counter: 3 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 39/90 ==============================
# time: 102.71s   lr = 0.001
#
# train average loss: 0.023  accuracy: 0.993
#
# valid average loss: 0.294  accuracy: 0.923
#
# ============================================================================
#
# EarlyStopping counter: 4 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 40/90 ==============================
# time: 102.66s   lr = 0.001
#
# train average loss: 0.021  accuracy: 0.993
#
# valid average loss: 0.303  accuracy: 0.921
#
# ============================================================================
#
# EarlyStopping counter: 5 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 41/90 ==============================
# time: 102.38s   lr = 0.001
#
# train average loss: 0.020  accuracy: 0.993
#
# valid average loss: 0.298  accuracy: 0.922
#
# ============================================================================
#
# EarlyStopping counter: 6 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 42/90 ==============================
# time: 102.49s   lr = 0.001
#
# train average loss: 0.021  accuracy: 0.994
#
# valid average loss: 0.298  accuracy: 0.921
#
# ============================================================================
#
# EarlyStopping counter: 7 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 43/90 ==============================
# time: 102.04s   lr = 0.001
#
# train average loss: 0.020  accuracy: 0.993
#
# valid average loss: 0.303  accuracy: 0.921
#
# ============================================================================
#
# EarlyStopping counter: 8 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 44/90 ==============================
# time: 102.92s   lr = 0.001
#
# train average loss: 0.019  accuracy: 0.994
#
# valid average loss: 0.302  accuracy: 0.923
#
# ============================================================================
#
# EarlyStopping counter: 9 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 45/90 ==============================
# time: 102.23s   lr = 0.001
#
# train average loss: 0.020  accuracy: 0.993
#
# valid average loss: 0.303  accuracy: 0.921
#
# ============================================================================
#
# EarlyStopping counter: 10 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 46/90 ==============================
# time: 102.14s   lr = 0.001
#
# train average loss: 0.020  accuracy: 0.994
#
# valid average loss: 0.300  accuracy: 0.922
#
# ============================================================================
# Epoch 00046: reducing learning rate of group 0 to 1.0000e-04.
#
# EarlyStopping counter: 11 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 47/90 ==============================
# time: 102.78s   lr = 0.0001
#
# train average loss: 0.018  accuracy: 0.995
#
# valid average loss: 0.297  accuracy: 0.922
#
# ============================================================================
#
# EarlyStopping counter: 12 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 48/90 ==============================
# time: 102.94s   lr = 0.0001
#
# train average loss: 0.017  accuracy: 0.995
#
# valid average loss: 0.300  accuracy: 0.923
#
# ============================================================================
#
# EarlyStopping counter: 13 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 49/90 ==============================
# time: 102.64s   lr = 0.0001
#
# train average loss: 0.017  accuracy: 0.995
#
# valid average loss: 0.310  accuracy: 0.923
#
# ============================================================================
#
# EarlyStopping counter: 14 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 50/90 ==============================
# time: 102.58s   lr = 0.0001
#
# train average loss: 0.016  accuracy: 0.995
#
# valid average loss: 0.302  accuracy: 0.924
#
# ============================================================================
#
# EarlyStopping counter: 15 out of 15
#
# ##########################
# ##### Early Stopping #####
# ##########################
#
# Total time for training is 5.1e+03s

# %%
def show_graphs(history, title):
    fig, ax = plt.subplots(1, 2, figsize=(12, 5))
    fig.suptitle(title, size=20)
    ax[0].plot(history['acc'], label='train accuracy')
    ax[0].plot(history['val_acc'], label='valid accuracy')
    ax[0].set_title('Accuracy')
    ax[0].set_xlabel('Epoch')
    ax[0].set_ylabel('Accuracy')
    ax[0].legend(loc='upper left')
    
    ax[1].plot(history['loss'], label='train loss')
    ax[1].plot(history['val_loss'], label='valid loss')
    ax[1].set_title('Loss')
    ax[1].set_xlabel('Epoch')
    ax[1].set_ylabel('Loss')
    ax[1].legend('upper left')

    plt.show()


title_list = ['case4: epoch 150 with lr 1e-4', 'case5: dropout rate 0.1', 'case6: remove conv layer']
historys = [history4, history5, history6]

for n in range(len(title_list)):
    show_graphs(historys[n], title_list[n])

# %% [markdown]
# ## Step 7. Evaluate performance of model

# %%
@torch.no_grad()
def eval(model, dataset, loss_func=nn.CrossEntropyLoss()):
    
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    model = model.to(device)

    model.eval() 
    batch_loss, batch_acc = 0, 0
    pbar = tqdm(enumerate(dataset), total=len(dataset))
    
    start = time.time()
    for batch, (images, labels) in pbar:
        images, labels = images.to(device), labels.to(device)
    
        outputs = model(images)
        loss = loss_func(outputs, labels)
        output_index = torch.argmax(outputs, dim=1)
        acc = (output_index==labels).sum()/len(outputs)

        batch_loss += loss.item()
        batch_acc += acc.item()

        del images; del labels; del outputs
        torch.cuda.empty_cache()

    end = time.time()

    print(f'\nTotal time for testing is {end-start:.2f}s')
    print(f'\nAverage loss: {batch_loss/(batch+1):.3f}  accuracy: {batch_acc/(batch+1):.3f}')

    return {
        'loss': batch_loss/(batch+1),
        'accuracy': batch_acc/(batch+1),
    }

# %%
result1 = eval(history4['model'], test_loader)
result2 = eval(history5['model'], test_loader)
result3 = eval(history6['model'], test_loader)
# Out:
#   0%|          | 0/79 [00:00<?, ?it/s]
# Total time for testing is 14.80s
#
# Average loss: 0.260  accuracy: 0.918
#   0%|          | 0/79 [00:00<?, ?it/s]
# Total time for testing is 15.08s
#
# Average loss: 0.372  accuracy: 0.920
#   0%|          | 0/79 [00:00<?, ?it/s]
# Total time for testing is 14.92s
#
# Average loss: 0.304  accuracy: 0.927
