# %% [markdown]
# <a href="https://colab.research.google.com/github/Sangh0/Classification/blob/main/alexnet_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AlexNet Practice
#
# ## Step 1. Import packages and modules

# %%
import os
import random
import time
import numpy as np
import matplotlib.pyplot as plt
from tqdm.auto import tqdm
from sklearn.model_selection import train_test_split
from multiprocessing import cpu_count

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.datasets as dset
import torchvision.models as models
from torch.utils.data import DataLoader, SubsetRandomSampler
from torchvision.datasets import ImageFolder
from torchsummary import summary

# %%
SEED = 42

def RANDOM_SEED(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    os.environ["PYTHONHASHSEED"] = str(seed)

RANDOM_SEED(SEED)

# %% [markdown]
# ## Step 2. Set hyperparameters

# %%
Config = {
    'batch_size': 128,
    'lr': 0.01,
    'epochs': 90,
    'weight_decay': 5e-4,
    'momentum': 0.9,
}

# %% [markdown]
# ## Step 3. Load Dataset

# %%
# augmentation
train_transforms_ = transforms.Compose([
    transforms.Resize((256,256)),
    transforms.RandomCrop((224,224)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
])

valid_transforms_ = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
])

# Load CIFAR-10 
# train: 50000 (5000 per class), test: 10000 (1000 per class)
train_data = dset.CIFAR10(
    root='./cifar10', 
    train=True, 
    download=True, 
    transform=train_transforms_,
)

test_data = dset.CIFAR10(
    root='./cifar10',
    train=False,
    download=True,
    transform=valid_transforms_,
)

# stratify split (train: 80%, valid: 20%)
train_index, valid_index = train_test_split(
    np.arange(len(train_data)),
    test_size=0.2,
    random_state=SEED,
    shuffle=True,
    stratify=train_data.targets,
)

# define data loaders for batch learning
train_loader = DataLoader(
    train_data,
    batch_size=Config['batch_size'],
    sampler=SubsetRandomSampler(train_index),
    drop_last=True,
    num_workers=int(cpu_count()/2),
)

valid_loader = DataLoader(
    train_data,
    batch_size=Config['batch_size'],
    sampler=SubsetRandomSampler(valid_index),
    drop_last=True,
    num_workers=int(cpu_count()/2),
)

test_loader = DataLoader(
    test_data,
    batch_size=Config['batch_size'],
    shuffle=False,
    drop_last=False,
    num_workers=int(cpu_count()/2),
)

classes = ('Airplane', 'Car', 'Bird', 'Cat', 'Deer', 'Dog', 'Frog', 'Horse', 'Ship', 'Truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ## Step 4-1. Build Model (Random Weights)

# %%
class AlexNet(nn.Module):
    
    def __init__(
        self,
        in_dim=3,
        filters=[96, 256, 384, 384, 256],
        dropout=0.5,
        num_classes=1000,
    ):
        super(AlexNet, self).__init__()
        
        self.features = nn.Sequential(
            nn.Conv2d(in_dim, filters[0], kernel_size=11, stride=4, padding=2),
            nn.ReLU(inplace=True),
            nn.LocalResponseNorm(size=5, alpha=0.0001, beta=0.75, k=2),
            nn.MaxPool2d(kernel_size=3, stride=2),
            
            nn.Conv2d(filters[0], filters[1], kernel_size=5, stride=1, padding=2),
            nn.ReLU(inplace=True),
            nn.LocalResponseNorm(size=5, alpha=0.0001, beta=0.75, k=2),
            nn.MaxPool2d(kernel_size=3, stride=2), 
            
            nn.Conv2d(filters[1], filters[2], kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(filters[2], filters[3], kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(filters[3], filters[4], kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
        )
        
        self.classifier = nn.Sequential(
            nn.Dropout(dropout),
            nn.Linear(filters[4]*6*6, 4096),
            nn.ReLU(inplace=True),

            nn.Dropout(dropout),
            nn.Linear(4096, 4096),
            nn.ReLU(inplace=True),
      
            nn.Linear(4096, num_classes),
        )

        self._init_weights_()
        
    def forward(self, x):
        B = x.size(0)
        x = self.features(x)
        x = x.view(B, -1)
        x = self.classifier(x)
        return x

    def _init_weights_(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.normal_(m.weight, mean=0, std=0.01)
                nn.init.constant_(m.bias, 1)
            elif isinstance(m, nn.Linear):
                nn.init.constant_(m.bias, 1)
        
        nn.init.constant_(self.features[0].bias, 0)
        nn.init.constant_(self.features[8].bias, 0)

# %% [markdown]
# ## Step 4-2. Build Model (pre-trained weights)

# %%
class AlexNet(nn.Module):

    def __init__(
        self,
        dropout=None,
        num_classes=1000,
        drop_one_conv=False,
        init_weights=False,
    ):
        super().__init__()

        self.model = models.alexnet(pretrained=True)

        if drop_one_conv:
            del self.model.features[8]
            del self.model.features[9]
            self.model.features[10] = nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1)

        if dropout is not None:
            self.model.classifier[0] = nn.Dropout(p=dropout, inplace=False)
            self.model.classifier[3] = nn.Dropout(p=dropout, inplace=False)
            
        self.model.classifier[-1] = nn.Linear(4096, num_classes)

        if init_weights:
            self._init_weights_()

    def forward(self, x):
        return self.model(x)

    def _init_weights_(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.normal_(m.weight, mean=0, std=0.01)
                nn.init.constant_(m.bias, 1)
            elif isinstance(m, nn.Linear):
                nn.init.constant_(m.bias, 1)
        
        nn.init.constant_(self.features[0].bias, 0)
        nn.init.constant_(self.features[8].bias, 0)

# %% [markdown]
# # Step 5. Set Callbacks

# %%
class EarlyStopping(object):
    
    def __init__(
        self, 
        patience=7, 
        verbose=False, 
        delta=0, 
        path='es_checkpoint.pt', 
        trace_func=print,
    ):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path
        self.trace_func = trace_func
        
    def __call__(self, val_loss, model):
        score = -val_loss
        if self.best_score is None:
            self.best_score = score
            self.save_model(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            self.trace_func(f'\nEarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_model(val_loss, model)
            self.counter = 0
            
    def save_model(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            self.trace_func(f'\nValidation loss decreased ({self.val_loss_min:.3f} --> {val_loss:.3f}).  Saving model ...')
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss

# %% [markdown]
# ## Step 6. Train Model

# %%
class TrainModel(object):
    
    def __init__(
        self,
        model,
        lr=Config['lr'],
        epochs=Config['epochs'],
        weight_decay=Config['weight_decay'],
        lr_scheduling=True,
        check_point=True,
        early_stop=False,
        es_path=None,
        train_log_step=10,
        valid_log_step=5,
    ):
        assert (early_stop==True and es_path is not None) or \
            (early_stop==False and es_path is None), \
            'If you set early stop, then es_path must be not None'

        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

        ######### Multi GPU training #########
        if torch.cuda.device_count() > 1:
            print("Let's use", torch.cuda.device_count(), "GPUs!")
            model = nn.DataParallel(model)
            self.model = model.to(self.device)
        ######################################

        ######### Single GPU training #########
        else:
            print('Single GPU training!')
            self.model = model.to(self.device)
        #######################################

        self.loss_func = nn.CrossEntropyLoss().to(self.device)
        
        self.epochs = epochs
        
        self.optimizer = optim.SGD(
            self.model.parameters(),
            momentum=Config['momentum'],
            lr=lr,
            weight_decay=weight_decay,
        )

        self.lr_scheduling = lr_scheduling
        self.lr_scheduler = optim.lr_scheduler.ReduceLROnPlateau(
            self.optimizer,
            mode='min',
            factor=0.1,
            patience=10,
            verbose=True,
            min_lr=lr*1e-2,
        )

        os.makedirs('./weights', exist_ok=True)
        es_path = './weights/'+es_path if es_path is not None else './weights/es_weight.pt'
        self.early_stop = early_stop
        self.es = EarlyStopping(patience=15, verbose=True, path=es_path)
        
        self.train_log_step = train_log_step
        self.valid_log_step = valid_log_step
        
    def fit(self, train_data, validation_data):
        print('Start Model Training...!')
        loss_list, acc_list = [], []
        val_loss_list, val_acc_list = [], []
        start_training = time.time()
        pbar = tqdm(range(self.epochs), total=int(self.epochs))
        for epoch in pbar:
            init_time = time.time()
            
            ######### Train Phase #########
            train_loss, train_acc = self.train_on_batch(
                train_data, self.train_log_step,
            )

            loss_list.append(train_loss)
            acc_list.append(train_acc)

            ######### Validate Phase #########
            valid_loss, valid_acc = self.validate_on_batch(
                validation_data, self.valid_log_step,
            )

            val_loss_list.append(valid_loss)
            val_acc_list.append(valid_acc)

            end_time = time.time()
            
            print(f'\n{"="*30} Epoch {epoch+1}/{self.epochs} {"="*30}'
                  f'\ntime: {end_time-init_time:.2f}s'
                  f'   lr = {self.optimizer.param_groups[0]["lr"]}')
            print(f'\ntrain average loss: {train_loss:.3f}'
                  f'  accuracy: {train_acc:.3f}')
            print(f'\nvalid average loss: {valid_loss:.3f}'
                  f'  accuracy: {valid_acc:.3f}')
            print(f'\n{"="*76}')
            
            if self.lr_scheduling:
                self.lr_scheduler.step(valid_loss)

            if self.early_stop:
                self.es(valid_loss, self.model)
                if self.es.early_stop:
                    print('\n##########################\n'
                          '##### Early Stopping #####\n'
                          '##########################')
                    break

        end_training = time.time()
        print(f'\nTotal time for training is {end_training-start_training:.2}s')
        
        return {
            'model': self.model,
            'loss': loss_list,
            'acc': acc_list,
            'val_loss': val_loss_list,
            'val_acc': val_acc_list,
        }
        
    @torch.no_grad()
    def validate_on_batch(self, validation_data, log_step):
        self.model.eval()
        batch_loss, batch_acc = 0, 0
        for batch, (images, labels) in enumerate(validation_data):
            images = images.to(self.device)
            labels = labels.to(self.device)
            
            outputs = self.model(images)
            loss = self.loss_func(outputs, labels)
            output_index = torch.argmax(outputs, dim=1)
            acc = (output_index==labels).sum()/len(outputs)
            
            if batch == 0:
                print(f'\n{" "*10} Validate Step {" "*10}')
                
            if (batch+1) % log_step == 0:
                print(f'\n[Batch {batch+1}/{len(validation_data)}]'
                      f'  valid loss: {loss:.3f}  accuracy: {acc:.3f}')
                
            batch_loss += loss.item()
            batch_acc += acc.item()
            
            del images; del labels; del outputs
            torch.cuda.empty_cache()
            
        return batch_loss/(batch+1), batch_acc/(batch+1)
        
    def train_on_batch(self, train_data, log_step):
        self.model.train()
        batch_loss, batch_acc = 0, 0
        for batch, (images, labels) in enumerate(train_data):
            images = images.to(self.device)
            labels = labels.to(self.device)

            self.optimizer.zero_grad()

            outputs = self.model(images)
            loss = self.loss_func(outputs, labels)
            output_index = torch.argmax(outputs, dim=1)
            acc = (output_index==labels).sum()/len(outputs)
            
            loss.backward()
            self.optimizer.step()
            
            
            if batch == 0:
                print(f'\n{" "*10} Train Step {" "*10}')
                
            if (batch+1) % log_step == 0:
                print(f'\n[Batch {batch+1}/{len(train_data)}]'
                      f'  train loss: {loss:.3f}  accuracy: {acc:.3f}')
                
            batch_loss += loss.item()
            batch_acc += acc.item()
            
            del images; del labels; del outputs
            torch.cuda.empty_cache()
        
        return batch_loss/(batch+1), batch_acc/(batch+1)

# %%
# case 1: base model
base_alexnet = AlexNet(num_classes=10)
summary(base_alexnet, (3, 224, 224), device='cpu')

case1_model = TrainModel(
    model=base_alexnet,
    lr=1e-2,
    epochs=90,
    train_log_step=1000,
    valid_log_step=300,
    early_stop=True,
    es_path='base_model_es.pt',
)

history1 = case1_model.fit(train_loader, valid_loader)
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 55, 55]          23,296
#               ReLU-2           [-1, 64, 55, 55]               0
#          MaxPool2d-3           [-1, 64, 27, 27]               0
#             Conv2d-4          [-1, 192, 27, 27]         307,392
#               ReLU-5          [-1, 192, 27, 27]               0
#          MaxPool2d-6          [-1, 192, 13, 13]               0
#             Conv2d-7          [-1, 384, 13, 13]         663,936
#               ReLU-8          [-1, 384, 13, 13]               0
#             Conv2d-9          [-1, 256, 13, 13]         884,992
#              ReLU-10          [-1, 256, 13, 13]               0
#            Conv2d-11          [-1, 256, 13, 13]         590,080
#              ReLU-12          [-1, 256, 13, 13]               0
#         MaxPool2d-13            [-1, 256, 6, 6]               0
# AdaptiveAvgPool2d-14            [-1, 256, 6, 6]               0
#           Dropout-15                 [-1, 9216]               0
#            Linear-16                 [-1, 4096]      37,752,832
#              ReLU-17                 [-1, 4096]               0
#           Dropout-18                 [-1, 4096]               0
#            Linear-19                 [-1, 4096]      16,781,312
#              ReLU-20                 [-1, 4096]               0
#            Linear-21                   [-1, 10]          40,970
#           AlexNet-22                   [-1, 10]               0
# ================================================================
# Total params: 57,044,810
# Trainable params: 57,044,810
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 8.37
# Params size (MB): 217.61
# Estimated Total Size (MB): 226.55
# ----------------------------------------------------------------
# Single GPU training!
# Start Model Training...!
#   0%|          | 0/90 [00:00<?, ?it/s]
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 1/90 ==============================
# time: 73.51s   lr = 0.01
#
# train average loss: 0.866  accuracy: 0.699
#
# valid average loss: 0.609  accuracy: 0.789
#
# ============================================================================
#
# Validation loss decreased (inf --> 0.609).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 2/90 ==============================
# time: 90.45s   lr = 0.01
#
# train average loss: 0.555  accuracy: 0.808
#
# valid average loss: 0.450  accuracy: 0.845
#
# ============================================================================
#
# Validation loss decreased (0.609 --> 0.450).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 3/90 ==============================
# time: 91.25s   lr = 0.01
#
# train average loss: 0.451  accuracy: 0.845
#
# valid average loss: 0.428  accuracy: 0.856
#
# ============================================================================
#
# Validation loss decreased (0.450 --> 0.428).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 4/90 ==============================
# time: 91.68s   lr = 0.01
#
# train average loss: 0.391  accuracy: 0.865
#
# valid average loss: 0.394  accuracy: 0.864
#
# ============================================================================
#
# Validation loss decreased (0.428 --> 0.394).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 5/90 ==============================
# time: 91.63s   lr = 0.01
#
# train average loss: 0.361  accuracy: 0.874
#
# valid average loss: 0.409  accuracy: 0.860
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 6/90 ==============================
# time: 92.31s   lr = 0.01
#
# train average loss: 0.326  accuracy: 0.887
#
# valid average loss: 0.373  accuracy: 0.875
#
# ============================================================================
#
# Validation loss decreased (0.394 --> 0.373).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 7/90 ==============================
# time: 92.09s   lr = 0.01
#
# train average loss: 0.294  accuracy: 0.897
#
# valid average loss: 0.386  accuracy: 0.867
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 8/90 ==============================
# time: 92.24s   lr = 0.01
#
# train average loss: 0.272  accuracy: 0.905
#
# valid average loss: 0.350  accuracy: 0.883
#
# ============================================================================
#
# Validation loss decreased (0.373 --> 0.350).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 9/90 ==============================
# time: 92.81s   lr = 0.01
#
# train average loss: 0.252  accuracy: 0.912
#
# valid average loss: 0.325  accuracy: 0.886
#
# ============================================================================
#
# Validation loss decreased (0.350 --> 0.325).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 10/90 ==============================
# time: 92.77s   lr = 0.01
#
# train average loss: 0.231  accuracy: 0.919
#
# valid average loss: 0.335  accuracy: 0.887
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 11/90 ==============================
# time: 92.59s   lr = 0.01
#
# train average loss: 0.222  accuracy: 0.921
#
# valid average loss: 0.329  accuracy: 0.887
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 12/90 ==============================
# time: 92.98s   lr = 0.01
#
# train average loss: 0.199  accuracy: 0.930
#
# valid average loss: 0.352  accuracy: 0.884
#
# ============================================================================
#
# EarlyStopping counter: 3 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 13/90 ==============================
# time: 91.94s   lr = 0.01
#
# train average loss: 0.189  accuracy: 0.933
#
# valid average loss: 0.353  accuracy: 0.884
#
# ============================================================================
#
# EarlyStopping counter: 4 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 14/90 ==============================
# time: 93.08s   lr = 0.01
#
# train average loss: 0.186  accuracy: 0.934
#
# valid average loss: 0.317  accuracy: 0.894
#
# ============================================================================
#
# Validation loss decreased (0.325 --> 0.317).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 15/90 ==============================
# time: 92.64s   lr = 0.01
#
# train average loss: 0.170  accuracy: 0.939
#
# valid average loss: 0.310  accuracy: 0.902
#
# ============================================================================
#
# Validation loss decreased (0.317 --> 0.310).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 16/90 ==============================
# time: 92.34s   lr = 0.01
#
# train average loss: 0.159  accuracy: 0.943
#
# valid average loss: 0.350  accuracy: 0.890
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 17/90 ==============================
# time: 92.23s   lr = 0.01
#
# train average loss: 0.157  accuracy: 0.944
#
# valid average loss: 0.328  accuracy: 0.897
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 18/90 ==============================
# time: 92.91s   lr = 0.01
#
# train average loss: 0.152  accuracy: 0.946
#
# valid average loss: 0.311  accuracy: 0.901
#
# ============================================================================
#
# EarlyStopping counter: 3 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 19/90 ==============================
# time: 92.87s   lr = 0.01
#
# train average loss: 0.136  accuracy: 0.953
#
# valid average loss: 0.325  accuracy: 0.898
#
# ============================================================================
#
# EarlyStopping counter: 4 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 20/90 ==============================
# time: 92.94s   lr = 0.01
#
# train average loss: 0.132  accuracy: 0.953
#
# valid average loss: 0.350  accuracy: 0.890
#
# ============================================================================
#
# EarlyStopping counter: 5 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 21/90 ==============================
# time: 92.53s   lr = 0.01
#
# train average loss: 0.133  accuracy: 0.953
#
# valid average loss: 0.306  accuracy: 0.899
#
# ============================================================================
#
# Validation loss decreased (0.310 --> 0.306).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 22/90 ==============================
# time: 92.64s   lr = 0.01
#
# train average loss: 0.125  accuracy: 0.956
#
# valid average loss: 0.327  accuracy: 0.898
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 23/90 ==============================
# time: 92.99s   lr = 0.01
#
# train average loss: 0.118  accuracy: 0.958
#
# valid average loss: 0.355  accuracy: 0.888
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 24/90 ==============================
# time: 92.38s   lr = 0.01
#
# train average loss: 0.116  accuracy: 0.959
#
# valid average loss: 0.332  accuracy: 0.895
#
# ============================================================================
#
# EarlyStopping counter: 3 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 25/90 ==============================
# time: 92.75s   lr = 0.01
#
# train average loss: 0.113  accuracy: 0.961
#
# valid average loss: 0.356  accuracy: 0.900
#
# ============================================================================
#
# EarlyStopping counter: 4 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 26/90 ==============================
# time: 92.73s   lr = 0.01
#
# train average loss: 0.107  accuracy: 0.963
#
# valid average loss: 0.354  accuracy: 0.899
#
# ============================================================================
#
# EarlyStopping counter: 5 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 27/90 ==============================
# time: 93.30s   lr = 0.01
#
# train average loss: 0.106  accuracy: 0.962
#
# valid average loss: 0.351  accuracy: 0.896
#
# ============================================================================
#
# EarlyStopping counter: 6 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 28/90 ==============================
# time: 93.32s   lr = 0.01
#
# train average loss: 0.110  accuracy: 0.961
#
# valid average loss: 0.301  accuracy: 0.902
#
# ============================================================================
#
# Validation loss decreased (0.306 --> 0.301).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 29/90 ==============================
# time: 94.06s   lr = 0.01
#
# train average loss: 0.099  accuracy: 0.966
#
# valid average loss: 0.347  accuracy: 0.895
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 30/90 ==============================
# time: 93.88s   lr = 0.01
#
# train average loss: 0.101  accuracy: 0.965
#
# valid average loss: 0.326  accuracy: 0.897
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 31/90 ==============================
# time: 91.93s   lr = 0.01
#
# train average loss: 0.092  accuracy: 0.969
#
# valid average loss: 0.339  accuracy: 0.896
#
# ============================================================================
#
# EarlyStopping counter: 3 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 32/90 ==============================
# time: 91.79s   lr = 0.01
#
# train average loss: 0.094  accuracy: 0.967
#
# valid average loss: 0.354  accuracy: 0.896
#
# ============================================================================
#
# EarlyStopping counter: 4 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 33/90 ==============================
# time: 92.37s   lr = 0.01
#
# train average loss: 0.093  accuracy: 0.967
#
# valid average loss: 0.343  accuracy: 0.898
#
# ============================================================================
#
# EarlyStopping counter: 5 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 34/90 ==============================
# time: 91.92s   lr = 0.01
#
# train average loss: 0.092  accuracy: 0.968
#
# valid average loss: 0.328  accuracy: 0.900
#
# ============================================================================
#
# EarlyStopping counter: 6 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 35/90 ==============================
# time: 91.78s   lr = 0.01
#
# train average loss: 0.097  accuracy: 0.966
#
# valid average loss: 0.337  accuracy: 0.894
#
# ============================================================================
#
# EarlyStopping counter: 7 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 36/90 ==============================
# time: 91.76s   lr = 0.01
#
# train average loss: 0.089  accuracy: 0.969
#
# valid average loss: 0.359  accuracy: 0.894
#
# ============================================================================
#
# EarlyStopping counter: 8 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 37/90 ==============================
# time: 92.30s   lr = 0.01
#
# train average loss: 0.085  accuracy: 0.971
#
# valid average loss: 0.324  accuracy: 0.902
#
# ============================================================================
#
# EarlyStopping counter: 9 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 38/90 ==============================
# time: 92.32s   lr = 0.01
#
# train average loss: 0.079  accuracy: 0.972
#
# valid average loss: 0.336  accuracy: 0.902
#
# ============================================================================
#
# EarlyStopping counter: 10 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 39/90 ==============================
# time: 92.29s   lr = 0.01
#
# train average loss: 0.089  accuracy: 0.969
#
# valid average loss: 0.353  accuracy: 0.897
#
# ============================================================================
# Epoch 00039: reducing learning rate of group 0 to 1.0000e-03.
#
# EarlyStopping counter: 11 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 40/90 ==============================
# time: 92.38s   lr = 0.001
#
# train average loss: 0.038  accuracy: 0.988
#
# valid average loss: 0.304  accuracy: 0.917
#
# ============================================================================
#
# EarlyStopping counter: 12 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 41/90 ==============================
# time: 91.60s   lr = 0.001
#
# train average loss: 0.027  accuracy: 0.992
#
# valid average loss: 0.300  accuracy: 0.916
#
# ============================================================================
#
# Validation loss decreased (0.301 --> 0.300).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 42/90 ==============================
# time: 93.03s   lr = 0.001
#
# train average loss: 0.025  accuracy: 0.992
#
# valid average loss: 0.295  accuracy: 0.919
#
# ============================================================================
#
# Validation loss decreased (0.300 --> 0.295).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 43/90 ==============================
# time: 94.54s   lr = 0.001
#
# train average loss: 0.023  accuracy: 0.993
#
# valid average loss: 0.294  accuracy: 0.921
#
# ============================================================================
#
# Validation loss decreased (0.295 --> 0.294).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 44/90 ==============================
# time: 93.12s   lr = 0.001
#
# train average loss: 0.020  accuracy: 0.994
#
# valid average loss: 0.306  accuracy: 0.918
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 45/90 ==============================
# time: 93.90s   lr = 0.001
#
# train average loss: 0.021  accuracy: 0.993
#
# valid average loss: 0.309  accuracy: 0.918
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 46/90 ==============================
# time: 93.93s   lr = 0.001
#
# train average loss: 0.019  accuracy: 0.994
#
# valid average loss: 0.311  accuracy: 0.918
#
# ============================================================================
#
# EarlyStopping counter: 3 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 47/90 ==============================
# time: 94.09s   lr = 0.001
#
# train average loss: 0.018  accuracy: 0.994
#
# valid average loss: 0.306  accuracy: 0.921
#
# ============================================================================
#
# EarlyStopping counter: 4 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 48/90 ==============================
# time: 93.74s   lr = 0.001
#
# train average loss: 0.018  accuracy: 0.994
#
# valid average loss: 0.310  accuracy: 0.920
#
# ============================================================================
#
# EarlyStopping counter: 5 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 49/90 ==============================
# time: 94.50s   lr = 0.001
#
# train average loss: 0.017  accuracy: 0.995
#
# valid average loss: 0.305  accuracy: 0.919
#
# ============================================================================
#
# EarlyStopping counter: 6 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 50/90 ==============================
# time: 93.37s   lr = 0.001
#
# train average loss: 0.016  accuracy: 0.995
#
# valid average loss: 0.304  accuracy: 0.922
#
# ============================================================================
#
# EarlyStopping counter: 7 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 51/90 ==============================
# time: 93.27s   lr = 0.001
#
# train average loss: 0.015  accuracy: 0.995
#
# valid average loss: 0.314  accuracy: 0.921
#
# ============================================================================
#
# EarlyStopping counter: 8 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 52/90 ==============================
# time: 94.16s   lr = 0.001
#
# train average loss: 0.014  accuracy: 0.996
#
# valid average loss: 0.307  accuracy: 0.922
#
# ============================================================================
#
# EarlyStopping counter: 9 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 53/90 ==============================
# time: 93.52s   lr = 0.001
#
# train average loss: 0.014  accuracy: 0.996
#
# valid average loss: 0.305  accuracy: 0.920
#
# ============================================================================
#
# EarlyStopping counter: 10 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 54/90 ==============================
# time: 92.07s   lr = 0.001
#
# train average loss: 0.014  accuracy: 0.996
#
# valid average loss: 0.302  accuracy: 0.921
#
# ============================================================================
# Epoch 00054: reducing learning rate of group 0 to 1.0000e-04.
#
# EarlyStopping counter: 11 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 55/90 ==============================
# time: 91.88s   lr = 0.0001
#
# train average loss: 0.013  accuracy: 0.997
#
# valid average loss: 0.308  accuracy: 0.920
#
# ============================================================================
#
# EarlyStopping counter: 12 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 56/90 ==============================
# time: 94.30s   lr = 0.0001
#
# train average loss: 0.012  accuracy: 0.996
#
# valid average loss: 0.308  accuracy: 0.921
#
# ============================================================================
#
# EarlyStopping counter: 13 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 57/90 ==============================
# time: 95.47s   lr = 0.0001
#
# train average loss: 0.013  accuracy: 0.996
#
# valid average loss: 0.306  accuracy: 0.923
#
# ============================================================================
#
# EarlyStopping counter: 14 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 58/90 ==============================
# time: 93.66s   lr = 0.0001
#
# train average loss: 0.013  accuracy: 0.997
#
# valid average loss: 0.308  accuracy: 0.923
#
# ============================================================================
#
# EarlyStopping counter: 15 out of 15
#
# ##########################
# ##### Early Stopping #####
# ##########################
#
# Total time for training is 5.4e+03s

# %%
# case 2: don't apply dropout layer
del_dropout_alexnet = AlexNet(dropout=0, num_classes=10)
summary(del_dropout_alexnet, (3, 224, 224), device='cpu')

case2_model = TrainModel(
    model=del_dropout_alexnet,
    lr=1e-2,
    epochs=90,
    train_log_step=1000,
    valid_log_step=300,
    early_stop=True,
    es_path='no_dropout_model_es.pt'
)

history2 = case2_model.fit(train_loader, valid_loader)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 55, 55]          23,296
#               ReLU-2           [-1, 64, 55, 55]               0
#          MaxPool2d-3           [-1, 64, 27, 27]               0
#             Conv2d-4          [-1, 192, 27, 27]         307,392
#               ReLU-5          [-1, 192, 27, 27]               0
#          MaxPool2d-6          [-1, 192, 13, 13]               0
#             Conv2d-7          [-1, 384, 13, 13]         663,936
#               ReLU-8          [-1, 384, 13, 13]               0
#             Conv2d-9          [-1, 256, 13, 13]         884,992
#              ReLU-10          [-1, 256, 13, 13]               0
#            Conv2d-11          [-1, 256, 13, 13]         590,080
#              ReLU-12          [-1, 256, 13, 13]               0
#         MaxPool2d-13            [-1, 256, 6, 6]               0
# AdaptiveAvgPool2d-14            [-1, 256, 6, 6]               0
#           Dropout-15                 [-1, 9216]               0
#            Linear-16                 [-1, 4096]      37,752,832
#              ReLU-17                 [-1, 4096]               0
#           Dropout-18                 [-1, 4096]               0
#            Linear-19                 [-1, 4096]      16,781,312
#              ReLU-20                 [-1, 4096]               0
#            Linear-21                   [-1, 10]          40,970
#           AlexNet-22                   [-1, 10]               0
# ================================================================
# Total params: 57,044,810
# Trainable params: 57,044,810
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 8.37
# Params size (MB): 217.61
# Estimated Total Size (MB): 226.55
# ----------------------------------------------------------------
# Single GPU training!
# Start Model Training...!
#   0%|          | 0/90 [00:00<?, ?it/s]
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 1/90 ==============================
# time: 115.07s   lr = 0.01
#
# train average loss: 0.780  accuracy: 0.726
#
# valid average loss: 0.512  accuracy: 0.818
#
# ============================================================================
#
# Validation loss decreased (inf --> 0.512).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 2/90 ==============================
# time: 116.25s   lr = 0.01
#
# train average loss: 0.453  accuracy: 0.841
#
# valid average loss: 0.408  accuracy: 0.858
#
# ============================================================================
#
# Validation loss decreased (0.512 --> 0.408).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 3/90 ==============================
# time: 114.75s   lr = 0.01
#
# train average loss: 0.349  accuracy: 0.877
#
# valid average loss: 0.412  accuracy: 0.858
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 4/90 ==============================
# time: 115.00s   lr = 0.01
#
# train average loss: 0.282  accuracy: 0.900
#
# valid average loss: 0.391  accuracy: 0.873
#
# ============================================================================
#
# Validation loss decreased (0.408 --> 0.391).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 5/90 ==============================
# time: 114.02s   lr = 0.01
#
# train average loss: 0.238  accuracy: 0.915
#
# valid average loss: 0.419  accuracy: 0.854
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 6/90 ==============================
# time: 114.37s   lr = 0.01
#
# train average loss: 0.204  accuracy: 0.929
#
# valid average loss: 0.381  accuracy: 0.873
#
# ============================================================================
#
# Validation loss decreased (0.391 --> 0.381).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 7/90 ==============================
# time: 114.29s   lr = 0.01
#
# train average loss: 0.167  accuracy: 0.941
#
# valid average loss: 0.357  accuracy: 0.884
#
# ============================================================================
#
# Validation loss decreased (0.381 --> 0.357).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 8/90 ==============================
# time: 113.44s   lr = 0.01
#
# train average loss: 0.141  accuracy: 0.950
#
# valid average loss: 0.405  accuracy: 0.880
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 9/90 ==============================
# time: 115.14s   lr = 0.01
#
# train average loss: 0.123  accuracy: 0.957
#
# valid average loss: 0.382  accuracy: 0.889
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 10/90 ==============================
# time: 114.34s   lr = 0.01
#
# train average loss: 0.105  accuracy: 0.963
#
# valid average loss: 0.373  accuracy: 0.887
#
# ============================================================================
#
# EarlyStopping counter: 3 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 11/90 ==============================
# time: 114.20s   lr = 0.01
#
# train average loss: 0.091  accuracy: 0.969
#
# valid average loss: 0.407  accuracy: 0.881
#
# ============================================================================
#
# EarlyStopping counter: 4 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 12/90 ==============================
# time: 114.62s   lr = 0.01
#
# train average loss: 0.083  accuracy: 0.971
#
# valid average loss: 0.393  accuracy: 0.893
#
# ============================================================================
#
# EarlyStopping counter: 5 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 13/90 ==============================
# time: 115.63s   lr = 0.01
#
# train average loss: 0.075  accuracy: 0.975
#
# valid average loss: 0.386  accuracy: 0.889
#
# ============================================================================
#
# EarlyStopping counter: 6 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 14/90 ==============================
# time: 114.33s   lr = 0.01
#
# train average loss: 0.072  accuracy: 0.975
#
# valid average loss: 0.362  accuracy: 0.891
#
# ============================================================================
#
# EarlyStopping counter: 7 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 15/90 ==============================
# time: 115.00s   lr = 0.01
#
# train average loss: 0.057  accuracy: 0.981
#
# valid average loss: 0.418  accuracy: 0.889
#
# ============================================================================
#
# EarlyStopping counter: 8 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 16/90 ==============================
# time: 114.52s   lr = 0.01
#
# train average loss: 0.058  accuracy: 0.981
#
# valid average loss: 0.416  accuracy: 0.891
#
# ============================================================================
#
# EarlyStopping counter: 9 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 17/90 ==============================
# time: 115.71s   lr = 0.01
#
# train average loss: 0.053  accuracy: 0.983
#
# valid average loss: 0.406  accuracy: 0.887
#
# ============================================================================
#
# EarlyStopping counter: 10 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 18/90 ==============================
# time: 114.61s   lr = 0.01
#
# train average loss: 0.051  accuracy: 0.983
#
# valid average loss: 0.488  accuracy: 0.868
#
# ============================================================================
# Epoch 00018: reducing learning rate of group 0 to 1.0000e-03.
#
# EarlyStopping counter: 11 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 19/90 ==============================
# time: 114.71s   lr = 0.001
#
# train average loss: 0.019  accuracy: 0.995
#
# valid average loss: 0.359  accuracy: 0.905
#
# ============================================================================
#
# EarlyStopping counter: 12 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 20/90 ==============================
# time: 115.40s   lr = 0.001
#
# train average loss: 0.010  accuracy: 0.997
#
# valid average loss: 0.376  accuracy: 0.907
#
# ============================================================================
#
# EarlyStopping counter: 13 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 21/90 ==============================
# time: 115.39s   lr = 0.001
#
# train average loss: 0.009  accuracy: 0.998
#
# valid average loss: 0.370  accuracy: 0.907
#
# ============================================================================
#
# EarlyStopping counter: 14 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 22/90 ==============================
# time: 114.48s   lr = 0.001
#
# train average loss: 0.007  accuracy: 0.998
#
# valid average loss: 0.365  accuracy: 0.911
#
# ============================================================================
#
# EarlyStopping counter: 15 out of 15
#
# ##########################
# ##### Early Stopping #####
# ##########################
#
# Total time for training is 2.5e+03s

# %%
# case 3: lower learning rate 1e-4
reduce_lr_alexnet = AlexNet(num_classes=10)
summary(reduce_lr_alexnet, (3, 224, 224), device='cpu')

case3_model = TrainModel(
    model=reduce_lr_alexnet,
    lr=1e-4,
    epochs=90,
    train_log_step=1000,
    valid_log_step=300,
    early_stop=True,
    es_path='lower_lr_model_es.pt',
)

history3 = case3_model.fit(train_loader, valid_loader)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 55, 55]          23,296
#               ReLU-2           [-1, 64, 55, 55]               0
#          MaxPool2d-3           [-1, 64, 27, 27]               0
#             Conv2d-4          [-1, 192, 27, 27]         307,392
#               ReLU-5          [-1, 192, 27, 27]               0
#          MaxPool2d-6          [-1, 192, 13, 13]               0
#             Conv2d-7          [-1, 384, 13, 13]         663,936
#               ReLU-8          [-1, 384, 13, 13]               0
#             Conv2d-9          [-1, 256, 13, 13]         884,992
#              ReLU-10          [-1, 256, 13, 13]               0
#            Conv2d-11          [-1, 256, 13, 13]         590,080
#              ReLU-12          [-1, 256, 13, 13]               0
#         MaxPool2d-13            [-1, 256, 6, 6]               0
# AdaptiveAvgPool2d-14            [-1, 256, 6, 6]               0
#           Dropout-15                 [-1, 9216]               0
#            Linear-16                 [-1, 4096]      37,752,832
#              ReLU-17                 [-1, 4096]               0
#           Dropout-18                 [-1, 4096]               0
#            Linear-19                 [-1, 4096]      16,781,312
#              ReLU-20                 [-1, 4096]               0
#            Linear-21                   [-1, 10]          40,970
#           AlexNet-22                   [-1, 10]               0
# ================================================================
# Total params: 57,044,810
# Trainable params: 57,044,810
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 8.37
# Params size (MB): 217.61
# Estimated Total Size (MB): 226.55
# ----------------------------------------------------------------
# Single GPU training!
# Start Model Training...!
#   0%|          | 0/90 [00:00<?, ?it/s]
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 1/90 ==============================
# time: 115.10s   lr = 0.0001
#
# train average loss: 1.203  accuracy: 0.588
#
# valid average loss: 0.744  accuracy: 0.745
#
# ============================================================================
#
# Validation loss decreased (inf --> 0.744).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 2/90 ==============================
# time: 115.25s   lr = 0.0001
#
# train average loss: 0.740  accuracy: 0.740
#
# valid average loss: 0.609  accuracy: 0.786
#
# ============================================================================
#
# Validation loss decreased (0.744 --> 0.609).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 3/90 ==============================
# time: 115.01s   lr = 0.0001
#
# train average loss: 0.644  accuracy: 0.773
#
# valid average loss: 0.563  accuracy: 0.805
#
# ============================================================================
#
# Validation loss decreased (0.609 --> 0.563).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 4/90 ==============================
# time: 113.91s   lr = 0.0001
#
# train average loss: 0.598  accuracy: 0.791
#
# valid average loss: 0.519  accuracy: 0.820
#
# ============================================================================
#
# Validation loss decreased (0.563 --> 0.519).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 5/90 ==============================
# time: 114.52s   lr = 0.0001
#
# train average loss: 0.565  accuracy: 0.802
#
# valid average loss: 0.496  accuracy: 0.825
#
# ============================================================================
#
# Validation loss decreased (0.519 --> 0.496).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 6/90 ==============================
# time: 113.60s   lr = 0.0001
#
# train average loss: 0.538  accuracy: 0.811
#
# valid average loss: 0.480  accuracy: 0.827
#
# ============================================================================
#
# Validation loss decreased (0.496 --> 0.480).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 7/90 ==============================
# time: 113.98s   lr = 0.0001
#
# train average loss: 0.516  accuracy: 0.820
#
# valid average loss: 0.459  accuracy: 0.843
#
# ============================================================================
#
# Validation loss decreased (0.480 --> 0.459).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 8/90 ==============================
# time: 114.03s   lr = 0.0001
#
# train average loss: 0.501  accuracy: 0.825
#
# valid average loss: 0.455  accuracy: 0.840
#
# ============================================================================
#
# Validation loss decreased (0.459 --> 0.455).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 9/90 ==============================
# time: 114.10s   lr = 0.0001
#
# train average loss: 0.484  accuracy: 0.831
#
# valid average loss: 0.434  accuracy: 0.851
#
# ============================================================================
#
# Validation loss decreased (0.455 --> 0.434).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 10/90 ==============================
# time: 113.35s   lr = 0.0001
#
# train average loss: 0.466  accuracy: 0.837
#
# valid average loss: 0.433  accuracy: 0.848
#
# ============================================================================
#
# Validation loss decreased (0.434 --> 0.433).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 11/90 ==============================
# time: 114.16s   lr = 0.0001
#
# train average loss: 0.459  accuracy: 0.839
#
# valid average loss: 0.419  accuracy: 0.852
#
# ============================================================================
#
# Validation loss decreased (0.433 --> 0.419).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 12/90 ==============================
# time: 113.81s   lr = 0.0001
#
# train average loss: 0.449  accuracy: 0.842
#
# valid average loss: 0.410  accuracy: 0.858
#
# ============================================================================
#
# Validation loss decreased (0.419 --> 0.410).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 13/90 ==============================
# time: 113.35s   lr = 0.0001
#
# train average loss: 0.439  accuracy: 0.847
#
# valid average loss: 0.406  accuracy: 0.858
#
# ============================================================================
#
# Validation loss decreased (0.410 --> 0.406).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 14/90 ==============================
# time: 113.46s   lr = 0.0001
#
# train average loss: 0.430  accuracy: 0.849
#
# valid average loss: 0.399  accuracy: 0.862
#
# ============================================================================
#
# Validation loss decreased (0.406 --> 0.399).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 15/90 ==============================
# time: 114.11s   lr = 0.0001
#
# train average loss: 0.424  accuracy: 0.851
#
# valid average loss: 0.393  accuracy: 0.862
#
# ============================================================================
#
# Validation loss decreased (0.399 --> 0.393).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 16/90 ==============================
# time: 112.91s   lr = 0.0001
#
# train average loss: 0.411  accuracy: 0.856
#
# valid average loss: 0.390  accuracy: 0.863
#
# ============================================================================
#
# Validation loss decreased (0.393 --> 0.390).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 17/90 ==============================
# time: 113.65s   lr = 0.0001
#
# train average loss: 0.402  accuracy: 0.857
#
# valid average loss: 0.386  accuracy: 0.864
#
# ============================================================================
#
# Validation loss decreased (0.390 --> 0.386).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 18/90 ==============================
# time: 114.56s   lr = 0.0001
#
# train average loss: 0.398  accuracy: 0.860
#
# valid average loss: 0.369  accuracy: 0.871
#
# ============================================================================
#
# Validation loss decreased (0.386 --> 0.369).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 19/90 ==============================
# time: 113.98s   lr = 0.0001
#
# train average loss: 0.393  accuracy: 0.863
#
# valid average loss: 0.371  accuracy: 0.872
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 20/90 ==============================
# time: 114.21s   lr = 0.0001
#
# train average loss: 0.389  accuracy: 0.864
#
# valid average loss: 0.364  accuracy: 0.873
#
# ============================================================================
#
# Validation loss decreased (0.369 --> 0.364).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 21/90 ==============================
# time: 113.33s   lr = 0.0001
#
# train average loss: 0.384  accuracy: 0.866
#
# valid average loss: 0.367  accuracy: 0.874
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 22/90 ==============================
# time: 114.13s   lr = 0.0001
#
# train average loss: 0.376  accuracy: 0.870
#
# valid average loss: 0.365  accuracy: 0.872
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 23/90 ==============================
# time: 113.67s   lr = 0.0001
#
# train average loss: 0.370  accuracy: 0.871
#
# valid average loss: 0.365  accuracy: 0.874
#
# ============================================================================
#
# EarlyStopping counter: 3 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 24/90 ==============================
# time: 114.43s   lr = 0.0001
#
# train average loss: 0.369  accuracy: 0.871
#
# valid average loss: 0.353  accuracy: 0.878
#
# ============================================================================
#
# Validation loss decreased (0.364 --> 0.353).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 25/90 ==============================
# time: 113.15s   lr = 0.0001
#
# train average loss: 0.360  accuracy: 0.874
#
# valid average loss: 0.353  accuracy: 0.876
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 26/90 ==============================
# time: 113.55s   lr = 0.0001
#
# train average loss: 0.354  accuracy: 0.877
#
# valid average loss: 0.345  accuracy: 0.877
#
# ============================================================================
#
# Validation loss decreased (0.353 --> 0.345).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 27/90 ==============================
# time: 113.04s   lr = 0.0001
#
# train average loss: 0.351  accuracy: 0.876
#
# valid average loss: 0.348  accuracy: 0.880
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 28/90 ==============================
# time: 113.67s   lr = 0.0001
#
# train average loss: 0.343  accuracy: 0.881
#
# valid average loss: 0.346  accuracy: 0.880
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 29/90 ==============================
# time: 114.11s   lr = 0.0001
#
# train average loss: 0.343  accuracy: 0.881
#
# valid average loss: 0.342  accuracy: 0.881
#
# ============================================================================
#
# Validation loss decreased (0.345 --> 0.342).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 30/90 ==============================
# time: 114.07s   lr = 0.0001
#
# train average loss: 0.341  accuracy: 0.881
#
# valid average loss: 0.342  accuracy: 0.882
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 31/90 ==============================
# time: 114.07s   lr = 0.0001
#
# train average loss: 0.339  accuracy: 0.882
#
# valid average loss: 0.341  accuracy: 0.883
#
# ============================================================================
#
# Validation loss decreased (0.342 --> 0.341).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 32/90 ==============================
# time: 114.30s   lr = 0.0001
#
# train average loss: 0.336  accuracy: 0.882
#
# valid average loss: 0.332  accuracy: 0.887
#
# ============================================================================
#
# Validation loss decreased (0.341 --> 0.332).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 33/90 ==============================
# time: 113.42s   lr = 0.0001
#
# train average loss: 0.332  accuracy: 0.882
#
# valid average loss: 0.338  accuracy: 0.882
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 34/90 ==============================
# time: 113.22s   lr = 0.0001
#
# train average loss: 0.321  accuracy: 0.886
#
# valid average loss: 0.332  accuracy: 0.885
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 35/90 ==============================
# time: 113.36s   lr = 0.0001
#
# train average loss: 0.326  accuracy: 0.885
#
# valid average loss: 0.328  accuracy: 0.889
#
# ============================================================================
#
# Validation loss decreased (0.332 --> 0.328).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 36/90 ==============================
# time: 114.86s   lr = 0.0001
#
# train average loss: 0.316  accuracy: 0.891
#
# valid average loss: 0.338  accuracy: 0.884
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 37/90 ==============================
# time: 113.87s   lr = 0.0001
#
# train average loss: 0.315  accuracy: 0.890
#
# valid average loss: 0.329  accuracy: 0.886
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 38/90 ==============================
# time: 114.16s   lr = 0.0001
#
# train average loss: 0.314  accuracy: 0.890
#
# valid average loss: 0.330  accuracy: 0.888
#
# ============================================================================
#
# EarlyStopping counter: 3 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 39/90 ==============================
# time: 114.52s   lr = 0.0001
#
# train average loss: 0.308  accuracy: 0.890
#
# valid average loss: 0.318  accuracy: 0.889
#
# ============================================================================
#
# Validation loss decreased (0.328 --> 0.318).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 40/90 ==============================
# time: 114.23s   lr = 0.0001
#
# train average loss: 0.309  accuracy: 0.892
#
# valid average loss: 0.319  accuracy: 0.889
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 41/90 ==============================
# time: 114.19s   lr = 0.0001
#
# train average loss: 0.302  accuracy: 0.894
#
# valid average loss: 0.314  accuracy: 0.890
#
# ============================================================================
#
# Validation loss decreased (0.318 --> 0.314).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 42/90 ==============================
# time: 114.14s   lr = 0.0001
#
# train average loss: 0.303  accuracy: 0.893
#
# valid average loss: 0.321  accuracy: 0.888
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 43/90 ==============================
# time: 113.73s   lr = 0.0001
#
# train average loss: 0.298  accuracy: 0.896
#
# valid average loss: 0.320  accuracy: 0.888
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 44/90 ==============================
# time: 114.55s   lr = 0.0001
#
# train average loss: 0.294  accuracy: 0.896
#
# valid average loss: 0.322  accuracy: 0.888
#
# ============================================================================
#
# EarlyStopping counter: 3 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 45/90 ==============================
# time: 113.76s   lr = 0.0001
#
# train average loss: 0.294  accuracy: 0.897
#
# valid average loss: 0.313  accuracy: 0.892
#
# ============================================================================
#
# Validation loss decreased (0.314 --> 0.313).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 46/90 ==============================
# time: 114.30s   lr = 0.0001
#
# train average loss: 0.290  accuracy: 0.898
#
# valid average loss: 0.314  accuracy: 0.890
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 47/90 ==============================
# time: 114.27s   lr = 0.0001
#
# train average loss: 0.289  accuracy: 0.898
#
# valid average loss: 0.314  accuracy: 0.892
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 48/90 ==============================
# time: 113.81s   lr = 0.0001
#
# train average loss: 0.283  accuracy: 0.901
#
# valid average loss: 0.313  accuracy: 0.890
#
# ============================================================================
#
# EarlyStopping counter: 3 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 49/90 ==============================
# time: 114.90s   lr = 0.0001
#
# train average loss: 0.284  accuracy: 0.900
#
# valid average loss: 0.306  accuracy: 0.896
#
# ============================================================================
#
# Validation loss decreased (0.313 --> 0.306).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 50/90 ==============================
# time: 114.24s   lr = 0.0001
#
# train average loss: 0.281  accuracy: 0.901
#
# valid average loss: 0.307  accuracy: 0.897
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 51/90 ==============================
# time: 114.10s   lr = 0.0001
#
# train average loss: 0.275  accuracy: 0.904
#
# valid average loss: 0.310  accuracy: 0.891
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 52/90 ==============================
# time: 113.16s   lr = 0.0001
#
# train average loss: 0.277  accuracy: 0.903
#
# valid average loss: 0.301  accuracy: 0.897
#
# ============================================================================
#
# Validation loss decreased (0.306 --> 0.301).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 53/90 ==============================
# time: 114.48s   lr = 0.0001
#
# train average loss: 0.278  accuracy: 0.903
#
# valid average loss: 0.304  accuracy: 0.895
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 54/90 ==============================
# time: 113.85s   lr = 0.0001
#
# train average loss: 0.269  accuracy: 0.906
#
# valid average loss: 0.300  accuracy: 0.900
#
# ============================================================================
#
# Validation loss decreased (0.301 --> 0.300).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 55/90 ==============================
# time: 113.28s   lr = 0.0001
#
# train average loss: 0.269  accuracy: 0.905
#
# valid average loss: 0.300  accuracy: 0.895
#
# ============================================================================
#
# Validation loss decreased (0.300 --> 0.300).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 56/90 ==============================
# time: 113.89s   lr = 0.0001
#
# train average loss: 0.267  accuracy: 0.906
#
# valid average loss: 0.306  accuracy: 0.896
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 57/90 ==============================
# time: 114.09s   lr = 0.0001
#
# train average loss: 0.261  accuracy: 0.909
#
# valid average loss: 0.307  accuracy: 0.898
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 58/90 ==============================
# time: 113.01s   lr = 0.0001
#
# train average loss: 0.262  accuracy: 0.907
#
# valid average loss: 0.305  accuracy: 0.895
#
# ============================================================================
#
# EarlyStopping counter: 3 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 59/90 ==============================
# time: 114.05s   lr = 0.0001
#
# train average loss: 0.264  accuracy: 0.907
#
# valid average loss: 0.296  accuracy: 0.899
#
# ============================================================================
#
# Validation loss decreased (0.300 --> 0.296).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 60/90 ==============================
# time: 113.26s   lr = 0.0001
#
# train average loss: 0.258  accuracy: 0.909
#
# valid average loss: 0.296  accuracy: 0.899
#
# ============================================================================
#
# Validation loss decreased (0.296 --> 0.296).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 61/90 ==============================
# time: 114.40s   lr = 0.0001
#
# train average loss: 0.255  accuracy: 0.911
#
# valid average loss: 0.297  accuracy: 0.897
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 62/90 ==============================
# time: 113.85s   lr = 0.0001
#
# train average loss: 0.252  accuracy: 0.911
#
# valid average loss: 0.299  accuracy: 0.897
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 63/90 ==============================
# time: 114.30s   lr = 0.0001
#
# train average loss: 0.254  accuracy: 0.910
#
# valid average loss: 0.301  accuracy: 0.898
#
# ============================================================================
#
# EarlyStopping counter: 3 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 64/90 ==============================
# time: 113.74s   lr = 0.0001
#
# train average loss: 0.254  accuracy: 0.909
#
# valid average loss: 0.301  accuracy: 0.895
#
# ============================================================================
#
# EarlyStopping counter: 4 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 65/90 ==============================
# time: 114.10s   lr = 0.0001
#
# train average loss: 0.254  accuracy: 0.911
#
# valid average loss: 0.298  accuracy: 0.900
#
# ============================================================================
#
# EarlyStopping counter: 5 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 66/90 ==============================
# time: 114.58s   lr = 0.0001
#
# train average loss: 0.246  accuracy: 0.914
#
# valid average loss: 0.300  accuracy: 0.897
#
# ============================================================================
#
# EarlyStopping counter: 6 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 67/90 ==============================
# time: 114.67s   lr = 0.0001
#
# train average loss: 0.248  accuracy: 0.912
#
# valid average loss: 0.301  accuracy: 0.899
#
# ============================================================================
#
# EarlyStopping counter: 7 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 68/90 ==============================
# time: 114.43s   lr = 0.0001
#
# train average loss: 0.247  accuracy: 0.913
#
# valid average loss: 0.293  accuracy: 0.900
#
# ============================================================================
#
# Validation loss decreased (0.296 --> 0.293).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 69/90 ==============================
# time: 114.48s   lr = 0.0001
#
# train average loss: 0.240  accuracy: 0.915
#
# valid average loss: 0.293  accuracy: 0.903
#
# ============================================================================
#
# Validation loss decreased (0.293 --> 0.293).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 70/90 ==============================
# time: 113.62s   lr = 0.0001
#
# train average loss: 0.243  accuracy: 0.916
#
# valid average loss: 0.296  accuracy: 0.899
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 71/90 ==============================
# time: 114.02s   lr = 0.0001
#
# train average loss: 0.236  accuracy: 0.917
#
# valid average loss: 0.284  accuracy: 0.904
#
# ============================================================================
#
# Validation loss decreased (0.293 --> 0.284).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 72/90 ==============================
# time: 114.73s   lr = 0.0001
#
# train average loss: 0.235  accuracy: 0.918
#
# valid average loss: 0.291  accuracy: 0.902
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 73/90 ==============================
# time: 113.61s   lr = 0.0001
#
# train average loss: 0.234  accuracy: 0.918
#
# valid average loss: 0.299  accuracy: 0.898
#
# ============================================================================
#
# EarlyStopping counter: 2 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 74/90 ==============================
# time: 114.64s   lr = 0.0001
#
# train average loss: 0.232  accuracy: 0.918
#
# valid average loss: 0.292  accuracy: 0.902
#
# ============================================================================
#
# EarlyStopping counter: 3 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 75/90 ==============================
# time: 113.71s   lr = 0.0001
#
# train average loss: 0.234  accuracy: 0.917
#
# valid average loss: 0.294  accuracy: 0.903
#
# ============================================================================
#
# EarlyStopping counter: 4 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 76/90 ==============================
# time: 114.38s   lr = 0.0001
#
# train average loss: 0.229  accuracy: 0.920
#
# valid average loss: 0.288  accuracy: 0.900
#
# ============================================================================
#
# EarlyStopping counter: 5 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 77/90 ==============================
# time: 114.19s   lr = 0.0001
#
# train average loss: 0.233  accuracy: 0.917
#
# valid average loss: 0.291  accuracy: 0.898
#
# ============================================================================
#
# EarlyStopping counter: 6 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 78/90 ==============================
# time: 113.12s   lr = 0.0001
#
# train average loss: 0.232  accuracy: 0.918
#
# valid average loss: 0.290  accuracy: 0.900
#
# ============================================================================
#
# EarlyStopping counter: 7 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 79/90 ==============================
# time: 113.56s   lr = 0.0001
#
# train average loss: 0.227  accuracy: 0.920
#
# valid average loss: 0.293  accuracy: 0.900
#
# ============================================================================
#
# EarlyStopping counter: 8 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 80/90 ==============================
# time: 114.39s   lr = 0.0001
#
# train average loss: 0.227  accuracy: 0.920
#
# valid average loss: 0.286  accuracy: 0.906
#
# ============================================================================
#
# EarlyStopping counter: 9 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 81/90 ==============================
# time: 113.66s   lr = 0.0001
#
# train average loss: 0.227  accuracy: 0.920
#
# valid average loss: 0.293  accuracy: 0.901
#
# ============================================================================
#
# EarlyStopping counter: 10 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 82/90 ==============================
# time: 115.03s   lr = 0.0001
#
# train average loss: 0.220  accuracy: 0.923
#
# valid average loss: 0.289  accuracy: 0.898
#
# ============================================================================
# Epoch 00082: reducing learning rate of group 0 to 1.0000e-05.
#
# EarlyStopping counter: 11 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 83/90 ==============================
# time: 114.06s   lr = 1e-05
#
# train average loss: 0.216  accuracy: 0.924
#
# valid average loss: 0.285  accuracy: 0.903
#
# ============================================================================
#
# EarlyStopping counter: 12 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 84/90 ==============================
# time: 114.08s   lr = 1e-05
#
# train average loss: 0.213  accuracy: 0.925
#
# valid average loss: 0.285  accuracy: 0.902
#
# ============================================================================
#
# EarlyStopping counter: 13 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 85/90 ==============================
# time: 114.39s   lr = 1e-05
#
# train average loss: 0.214  accuracy: 0.924
#
# valid average loss: 0.287  accuracy: 0.904
#
# ============================================================================
#
# EarlyStopping counter: 14 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 86/90 ==============================
# time: 114.31s   lr = 1e-05
#
# train average loss: 0.215  accuracy: 0.924
#
# valid average loss: 0.284  accuracy: 0.902
#
# ============================================================================
#
# Validation loss decreased (0.284 --> 0.284).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 87/90 ==============================
# time: 114.49s   lr = 1e-05
#
# train average loss: 0.211  accuracy: 0.926
#
# valid average loss: 0.287  accuracy: 0.903
#
# ============================================================================
#
# EarlyStopping counter: 1 out of 15
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 88/90 ==============================
# time: 115.77s   lr = 1e-05
#
# train average loss: 0.217  accuracy: 0.923
#
# valid average loss: 0.282  accuracy: 0.903
#
# ============================================================================
#
# Validation loss decreased (0.284 --> 0.282).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 89/90 ==============================
# time: 114.41s   lr = 1e-05
#
# train average loss: 0.211  accuracy: 0.926
#
# valid average loss: 0.279  accuracy: 0.902
#
# ============================================================================
#
# Validation loss decreased (0.282 --> 0.279).  Saving model ...
#
#            Train Step
#
#            Validate Step
#
# ============================== Epoch 90/90 ==============================
# time: 114.66s   lr = 1e-05
#
# train average loss: 0.210  accuracy: 0.926
#
# valid average loss: 0.279  accuracy: 0.906
#
# ============================================================================
#
# Validation loss decreased (0.279 --> 0.279).  Saving model ...
#
# Total time for training is 1e+04s

# %%
def show_graphs(history, title):
    fig, ax = plt.subplots(1, 2, figsize=(12, 5))
    fig.suptitle(title, size=20)
    ax[0].plot(history['acc'], label='train accuracy')
    ax[0].plot(history['val_acc'], label='valid accuracy')
    ax[0].set_title('Accuracy')
    ax[0].set_xlabel('Epoch')
    ax[0].set_ylabel('Accuracy')
    ax[0].legend(loc='upper left')
    
    ax[1].plot(history['loss'], label='train loss')
    ax[1].plot(history['val_loss'], label='valid loss')
    ax[1].set_title('Loss')
    ax[1].set_xlabel('Epoch')
    ax[1].set_ylabel('Loss')
    ax[1].legend('upper left')

    plt.show()


title_list = ['case1: base model', 'case2: no dropout', 'case3: lr 1e-4']
historys = [history1, history2, history3]

for n in range(len(title_list)):
    show_graphs(historys[n], title_list[n])

# %% [markdown]
# ## Step 7. Evaluate performance of model

# %%
@torch.no_grad()
def eval(model, dataset, loss_func=nn.CrossEntropyLoss()):
    
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    model = model.to(device)

    model.eval() 
    batch_loss, batch_acc = 0, 0
    pbar = tqdm(enumerate(dataset), total=len(dataset))
    
    start = time.time()
    for batch, (images, labels) in pbar:
        images, labels = images.to(device), labels.to(device)
    
        outputs = model(images)
        loss = loss_func(outputs, labels)
        output_index = torch.argmax(outputs, dim=1)
        acc = (output_index==labels).sum()/len(outputs)

        batch_loss += loss.item()
        batch_acc += acc.item()

        del images; del labels; del outputs
        torch.cuda.empty_cache()

    end = time.time()

    print(f'\nTotal time for testing is {end-start:.2f}s')
    print(f'\nAverage loss: {batch_loss/(batch+1):.3f}  accuracy: {batch_acc/(batch+1):.3f}')

    return {
        'loss': batch_loss/(batch+1),
        'accuracy': batch_acc/(batch+1),
    }

# %%
result1 = eval(history1['model'], test_loader)
result2 = eval(history2['model'], test_loader)
result3 = eval(history3['model'], test_loader)
# Out:
#   0%|          | 0/79 [00:00<?, ?it/s]
# Total time for testing is 15.39s
#
# Average loss: 0.316  accuracy: 0.926
#   0%|          | 0/79 [00:00<?, ?it/s]
# Total time for testing is 15.23s
#
# Average loss: 0.384  accuracy: 0.911
#   0%|          | 0/79 [00:00<?, ?it/s]
# Total time for testing is 15.08s
#
# Average loss: 0.269  accuracy: 0.913
